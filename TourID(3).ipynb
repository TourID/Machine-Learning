# %% [markdown]
# # Sistem Rekomendasi Destinasi Wisata Berbasis Collaborative Filtering
# <hr>

# %%
# !pip install -q kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !rm -rf data

# %%
! kaggle datasets list
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/__init__.py", line 7, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/api/kaggle_api_extended.py", line 398, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
! kaggle datasets download -d aprabowo/indonesia-tourism-destination
# Out:
# Dataset URL: https://www.kaggle.com/datasets/aprabowo/indonesia-tourism-destination
# License(s): copyright-authors
# indonesia-tourism-destination.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
import os

# %%
local_zip = 'indonesia-tourism-destination.zip'
target_extraction = '/content/data/'
file_check = "dataset"

try:
    if os.path.exists(os.path.join(target_extraction, file_check)):
        print("File Already Extracted")
    else:
        zip_ref = zipfile.ZipFile(local_zip, 'r')
        zip_ref.extractall(target_extraction)

except FileNotFoundError:
    print('Zip File Not Found!')

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.16.1

# %% [markdown]
# ## 1. Mengimpor Library Python yang Dibutuhkan

# %%
# Untuk pengolahan data
import pandas as pd
import numpy as np
from zipfile import ZipFile
from pathlib import Path

# Untuk visualisasi data
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
sns.set_palette('Set1')
sns.set()

# Untuk pemodelan
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Untuk menghilangkan warnings saat plotting seaborn
import warnings
warnings.filterwarnings('ignore')

# Untuk mengupload file
import os

# %% [markdown]
# ## 2. Menyiapkan Dataset yang digunakan

# %%
# Upload semua dataset yang dipakai
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# ## 3. Data Understanding

# %% [markdown]
# ### 3.1 Menyiapkan Data

# %%
# Menyimpan masing-masing dataset kedalam variabel

rating = pd.read_csv('data/tourism_rating.csv')
place = pd.read_csv('data/tourism_with_id.csv')
user = pd.read_csv('data/user.csv')

# %% [markdown]
# ### 3.2 Eksplorasi Fitur-fitur pada Data

# %% [markdown]
# #### 3.2.1. Data place

# %%
# Melihat gambaran data place

place.head(2)
# Out:
#    Place_Id        Place_Name  \
# 0         1  Monumen Nasional
# 1         2          Kota Tua
#
#                                          Description Category     City  Price  \
# 0  Monumen Nasional atau yang populer disingkat d...   Budaya  Jakarta  20000
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...   Budaya  Jakarta      0
#
#    Rating  Time_Minutes                                       Coordinate  \
# 0     4.6          15.0          {'lat': -6.1753924, 'lng': 106.8271528}
# 1     4.6          90.0  {'lat': -6.137644799999999, 'lng': 106.8171245}
#
#         Lat        Long  Unnamed: 11  Unnamed: 12
# 0 -6.175392  106.827153          NaN            1
# 1 -6.137645  106.817125          NaN            2

# %%
# Membuang kolom yang tidak dipakai

place = place.drop(['Unnamed: 11','Unnamed: 12'],axis=1)
place.head(2)
# Out:
#    Place_Id        Place_Name  \
# 0         1  Monumen Nasional
# 1         2          Kota Tua
#
#                                          Description Category     City  Price  \
# 0  Monumen Nasional atau yang populer disingkat d...   Budaya  Jakarta  20000
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...   Budaya  Jakarta      0
#
#    Rating  Time_Minutes                                       Coordinate  \
# 0     4.6          15.0          {'lat': -6.1753924, 'lng': 106.8271528}
# 1     4.6          90.0  {'lat': -6.137644799999999, 'lng': 106.8171245}
#
#         Lat        Long
# 0 -6.175392  106.827153
# 1 -6.137645  106.817125

# %%
place.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 437 entries, 0 to 436
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Place_Id      437 non-null    int64
#  1   Place_Name    437 non-null    object
#  2   Description   437 non-null    object
#  3   Category      437 non-null    object
#  4   City          437 non-null    object
#  5   Price         437 non-null    int64
#  6   Rating        437 non-null    float64
#  7   Time_Minutes  205 non-null    float64
#  8   Coordinate    437 non-null    object
#  9   Lat           437 non-null    float64
#  10  Long          437 non-null    float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 37.7+ KB

# %%
# Membuang kolom yang tidak dipakai

place = place.drop('Time_Minutes', axis=1)

# %%
df = pd.DataFrame(place)
print("Data sebelum diurutkan:")
print(df)
# Out:
# Data sebelum diurutkan:
#      Place_Id                                 Place_Name  \
# 0           1                           Monumen Nasional
# 1           2                                   Kota Tua
# 2           3                              Dunia Fantasi
# 3           4          Taman Mini Indonesia Indah (TMII)
# 4           5                   Atlantis Water Adventure
# ..        ...                                        ...
# 432       433                        Museum Mpu Tantular
# 433       434                              Taman Bungkul
# 434       435           Taman Air Mancur Menari Kenjeran
# 435       436               Taman Flora Bratang Surabaya
# 436       437  Gereja Perawan Maria Tak Berdosa Surabaya
#
#                                            Description       Category  \
# 0    Monumen Nasional atau yang populer disingkat d...         Budaya
# 1    Kota tua di Jakarta, yang juga bernama Kota Tu...         Budaya
# 2    Dunia Fantasi atau disebut juga Dufan adalah t...  Taman Hiburan
# 3    Taman Mini Indonesia Indah merupakan suatu kaw...  Taman Hiburan
# 4    Atlantis Water Adventure atau dikenal dengan A...  Taman Hiburan
# ..                                                 ...            ...
# 432  Museum Negeri Mpu Tantular adalah sebuah museu...         Budaya
# 433  Taman Bungkul adalah taman wisata kota yang te...  Taman Hiburan
# 434  Air mancur menari atau dancing fountain juga a...  Taman Hiburan
# 435  Taman Flora adalah salah satu taman kota di Su...  Taman Hiburan
# 436  Gereja Katolik Kelahiran Santa Perawan Maria m...  Tempat Ibadah
#
#          City   Price  Rating  \
# 0     Jakarta   20000     4.6
# 1     Jakarta       0     4.6
# 2     Jakarta  270000     4.6
# 3     Jakarta   10000     4.5
# 4     Jakarta   94000     4.5
# ..        ...     ...     ...
# 432  Surabaya    2000     4.4
# 433  Surabaya       0     4.6
# 434  Surabaya       0     4.4
# 435  Surabaya       0     4.6
# 436  Surabaya   10000     4.8
#
#                                           Coordinate       Lat        Long
# 0            {'lat': -6.1753924, 'lng': 106.8271528} -6.175392  106.827153
# 1    {'lat': -6.137644799999999, 'lng': 106.8171245} -6.137645  106.817125
# 2    {'lat': -6.125312399999999, 'lng': 106.8335377} -6.125312  106.833538
# 3    {'lat': -6.302445899999999, 'lng': 106.8951559} -6.302446  106.895156
# 4               {'lat': -6.12419, 'lng': 106.839134} -6.124190  106.839134
# ..                                               ...       ...         ...
# 432          {'lat': -7.4338593, 'lng': 112.7199058} -7.433859  112.719906
# 433  {'lat': -7.291346799999999, 'lng': 112.7398218} -7.291347  112.739822
# 434          {'lat': -7.2752955, 'lng': 112.7549381} -7.275296  112.754938
# 435  {'lat': -7.294330299999999, 'lng': 112.7617534} -7.294330  112.761753
# 436          {'lat': -7.2420758, 'lng': 112.7368158} -7.242076  112.736816
#
# [437 rows x 10 columns]

# %%
# Memfilter data berdasarkan rentang ID 1-20
# Memfilter data berdasarkan rentang ID 1-20
filter1 = df[(df['Place_Id'] >= 1) & (df['Place_Id'] <= 20)]

# Memfilter data berdasarkan rentang ID 85-105
filter2 = df[(df['Place_Id'] >= 85) & (df['Place_Id'] <= 105)]

# Memfilter data berdasarkan rentang ID 211-231
filter3 = df[(df['Place_Id'] >= 211) & (df['Place_Id'] <= 231)]

# Memfilter data berdasarkan rentang ID 335-355
filter4 = df[(df['Place_Id'] >= 335) & (df['Place_Id'] <= 355)]

# Memfilter data berdasarkan rentang ID 392-412
filter5 = df[(df['Place_Id'] >= 392) & (df['Place_Id'] <= 412)]

# Menggabungkan hasil filter
filtered_df = pd.concat([filter1, filter2, filter3, filter4, filter5])


# Mengurutkan dataset yang sudah difilter berdasarkan kolom 'ID'
place = filtered_df.sort_values(by='Place_Id')

# %%
# Menampilkan data setelah diurutkan
print("\nData setelah diurutkan:")
print(place)
# Out:
# Data setelah diurutkan:
#      Place_Id                         Place_Name  \
# 0           1                   Monumen Nasional
# 1           2                           Kota Tua
# 2           3                      Dunia Fantasi
# 3           4  Taman Mini Indonesia Indah (TMII)
# 4           5           Atlantis Water Adventure
# ..        ...                                ...
# 407       408            Kebun Binatang Surabaya
# 408       409                        Rumah Batik
# 409       410                  Ciputra Waterpark
# 410       411          Masjid Muhammad Cheng Hoo
# 411       412           Masjid Nasional Al-Akbar
#
#                                            Description       Category  \
# 0    Monumen Nasional atau yang populer disingkat d...         Budaya
# 1    Kota tua di Jakarta, yang juga bernama Kota Tu...         Budaya
# 2    Dunia Fantasi atau disebut juga Dufan adalah t...  Taman Hiburan
# 3    Taman Mini Indonesia Indah merupakan suatu kaw...  Taman Hiburan
# 4    Atlantis Water Adventure atau dikenal dengan A...  Taman Hiburan
# ..                                                 ...            ...
# 407  Kebun Binatang Surabaya (KBS) (Dialek Arekan: ...     Cagar Alam
# 408  Di rumah batik ini terdapat sekitar 2000 lemba...         Budaya
# 409  Ciputra Waterpark Surabaya – Bermain air di wa...  Taman Hiburan
# 410  Masjid Cheng Hoo Surabaya adalah Masjid bernua...  Tempat Ibadah
# 411  Masjid Nasional Al Akbar (atau biasa disebut M...  Tempat Ibadah
#
#          City   Price  Rating  \
# 0     Jakarta   20000     4.6
# 1     Jakarta       0     4.6
# 2     Jakarta  270000     4.6
# 3     Jakarta   10000     4.5
# 4     Jakarta   94000     4.5
# ..        ...     ...     ...
# 407  Surabaya   15000     4.3
# 408  Surabaya       0     4.5
# 409  Surabaya   95000     4.3
# 410  Surabaya       0     4.7
# 411  Surabaya       0     4.9
#
#                                           Coordinate       Lat        Long
# 0            {'lat': -6.1753924, 'lng': 106.8271528} -6.175392  106.827153
# 1    {'lat': -6.137644799999999, 'lng': 106.8171245} -6.137645  106.817125
# 2    {'lat': -6.125312399999999, 'lng': 106.8335377} -6.125312  106.833538
# 3    {'lat': -6.302445899999999, 'lng': 106.8951559} -6.302446  106.895156
# 4               {'lat': -6.12419, 'lng': 106.839134} -6.124190  106.839134
# ..                                               ...       ...         ...
# 407  {'lat': -7.295954599999999, 'lng': 112.7366094} -7.295955  112.736609
# 408   {'lat': -7.278735999999999, 'lng': 112.718453} -7.278736  112.718453
# 409          {'lat': -7.2861707, 'lng': 112.6333338} -7.286171  112.633334
# 410  {'lat': -7.252275399999999, 'lng': 112.7468796} -7.252275  112.746880
# 411  {'lat': -7.336614099999998, 'lng': 112.7151806} -7.336614  112.715181
#
# [104 rows x 10 columns]

# %% [markdown]
# ## Data Category

# %% [markdown]
# #### 3.2.2. Data rating

# %%
df_user = pd.DataFrame(user)

# Fungsi untuk menduplikasi dan membuat variasi data
def create_variation(df_user, n):
    dfs = [df_user.copy() for _ in range(n)]
    for i, df_var in enumerate(dfs):
        df_var['User_Id'] += i * len(df_user)  # Mengubah User_Id
    return pd.concat(dfs, ignore_index=True)

# Menduplikasi dan membuat variasi pada data
df_varied = create_variation(df_user, 3)  # 3 adalah jumlah variasi

print(df_varied)
# Out:
#      User_Id                     Location  Age
# 0          1        Semarang, Jawa Tengah   20
# 1          2           Bekasi, Jawa Barat   21
# 2          3          Cirebon, Jawa Barat   23
# 3          4           Bekasi, Jawa Barat   21
# 4          5    Lampung, Sumatera Selatan   20
# ..       ...                          ...  ...
# 895      896    Lampung, Sumatera Selatan   31
# 896      897  Palembang, Sumatera Selatan   39
# 897      898            Bogor, Jawa Barat   38
# 898      899          Sragen, Jawa Tengah   27
# 899      900         Ponorogo, Jawa Timur   26
#
# [900 rows x 3 columns]

# %%
#

# %%
# melihat gambaran data rating

rating.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0        1       179              3
# 1        1       344              2
# 2        1         5              5
# 3        1       373              3
# 4        1       101              4

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   User_Id        10000 non-null  int64
#  1   Place_Id       10000 non-null  int64
#  2   Place_Ratings  10000 non-null  int64
# dtypes: int64(3)
# memory usage: 234.5 KB

# %%
# Merubah data rating agar hanya berisi rating pada tempat wisata
rating = pd.merge(rating, place[['Place_Id']], how='right', on='Place_Id')
rating.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0       36         1              4
# 1       38         1              2
# 2       64         1              2
# 3       74         1              2
# 4       86         1              4

# %%
rating.shape
# Out:
# (2368, 3)

# %% [markdown]
# #### 3.2.3. Data user

# %%
# Melihat gambaran data user

user.head()
# Out:
#    User_Id                   Location  Age
# 0        1      Semarang, Jawa Tengah   20
# 1        2         Bekasi, Jawa Barat   21
# 2        3        Cirebon, Jawa Barat   23
# 3        4         Bekasi, Jawa Barat   21
# 4        5  Lampung, Sumatera Selatan   20

# %%
# Merubah data user agar hanya berisi user yang pernah megunjungi wisata

user = pd.merge(user, rating[['User_Id']], how='right', on='User_Id').sort_values('User_Id')
user.head()
# Out:
#       User_Id               Location  Age
# 83          1  Semarang, Jawa Tengah   20
# 415         1  Semarang, Jawa Tengah   20
# 1930        1  Semarang, Jawa Tengah   20
# 825         1  Semarang, Jawa Tengah   20
# 1637        1  Semarang, Jawa Tengah   20

# %%
# Melihat dataset user yang pernah memberi rating pada wisata

user.shape
# Out:
# (2368, 3)

# %% [markdown]
# ## 4. Eksplorasi Data

# %%
# Membuat dataframe berisi lokasi dengan jumlah rating terbanyak
top_10 = rating['Place_Id'].value_counts().reset_index()[0:10]
top_10.columns = ['Place_Id', 'count']  # Rename columns for easier access
top_10 = pd.merge(top_10, place[['Place_Id', 'Place_Name']], how='left', on='Place_Id')


# Membuat visualisasi wisata dengan jumlah rating terbanyak
plt.figure(figsize=(8, 5))
sns.barplot(x='count', y='Place_Name', data=top_10)
plt.title('Jumlah Tempat Wisata dengan Rating Terbanyak', pad=20)
plt.ylabel('Nama Lokasi')
plt.xlabel('Jumlah Rating')
plt.show()

# %%
# Membuat visualisasi jumlah kategori wisata

sns.countplot(y='Category', data=place)
plt.title('Perbandingan Jumlah Kategori Wisata ', pad=20)
plt.show()

# %%
# Membuat visualisasi distribusi usia user

plt.figure(figsize=(5,3))
sns.boxplot(user['Age']);
plt.title('Distribusi Usia User', pad=20)
plt.show()

# %%
# Membuat visualisasi distribusi harga masuk tempat wisata

plt.figure(figsize=(7,3))
sns.boxplot(place['Price'])
plt.title('Distribusi Harga Masuk Wisata ', pad=20)
plt.show()

# %%
# Memfilter asal kota dari user
askot = user['Location'].apply(lambda x : x.split(',')[0])

# Visualisasi asal kota dari user
plt.figure(figsize=(8,6))
sns.countplot(y=askot)
plt.title('Jumlah Asal Kota dari User')
plt.show()

# %% [markdown]
# ## 5. Persiapan Data untuk Pemodelan

# %% [markdown]
# ### 5.1. Membuat Salinan Data rating

# %%
# Membaca dataset untuk dilakukan encoding

df = rating.copy()
df.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0       36         1              4
# 1       38         1              2
# 2       64         1              2
# 3       74         1              2
# 4       86         1              4

# %% [markdown]
# ### 5.2. Melakukan Encoding

# %% [markdown]
# #### 5.2.1. Membuat Fungsi untuk Melakukan Encoding

# %%
def dict_encoder(col, data=df):

  # Mengubah kolom suatu dataframe menjadi list tanpa nilai yang sama
  unique_val = data[col].unique().tolist()

  # Melakukan encoding value kolom suatu dataframe ke angka
  val_to_val_encoded = {x: i for i, x in enumerate(unique_val)}

  # Melakukan proses encoding angka ke value dari kolom suatu dataframe
  val_encoded_to_val = {i: x for i, x in enumerate(unique_val)}
  return val_to_val_encoded, val_encoded_to_val

# %% [markdown]
# #### 5.2.2. Encoding dan Mapping Kolom User

# %%
# Encoding User_Id
user_to_user_encoded, user_encoded_to_user = dict_encoder('User_Id')

# Mapping User_Id ke dataframe
df['user'] = df['User_Id'].map(user_to_user_encoded)

# %% [markdown]
# #### 5.2.3. Encoding dan Mapping Kolom Place

# %%
# Encoding Place_Id
place_to_place_encoded, place_encoded_to_place = dict_encoder('Place_Id')

# Mapping Place_Id ke dataframe place
df['place'] = df['Place_Id'].map(place_to_place_encoded)
print(df)
# Out:
#       User_Id  Place_Id  Place_Ratings  user  place
# 0          36         1              4     0      0
# 1          38         1              2     1      0
# 2          64         1              2     2      0
# 3          74         1              2     3      0
# 4          86         1              4     4      0
# ...       ...       ...            ...   ...    ...
# 2363      191       412              3   292    103
# 2364      221       412              4   257    103
# 2365      226       412              5    87    103
# 2366      227       412              4    14    103
# 2367      262       412              1   134    103
#
# [2368 rows x 5 columns]

# %% [markdown]
# ### 5.3. Melihat Gambaran Data untuk Pemodelan

# %%
# Mendapatkan jumlah user dan place
num_users, num_place = len(user_to_user_encoded), len(place_to_place_encoded)

# Mengubah rating menjadi nilai float
df['Place_Ratings'] = df['Place_Ratings'].values.astype(np.float32)

# Mendapatkan nilai minimum dan maksimum rating
min_rating, max_rating = min(df['Place_Ratings']), max(df['Place_Ratings'])

print(f'Number of User: {num_users}, Number of Place: {num_place}, Min Rating: {min_rating}, Max Rating: {max_rating}')
# Out:
# Number of User: 300, Number of Place: 104, Min Rating: 1.0, Max Rating: 5.0

# %%
# Mengacak dataset
df = df.sample(frac=1, random_state=42)
df.head(2)
# Out:
#       User_Id  Place_Id  Place_Ratings  user  place
# 1094      289       217            2.0   242     47
# 188        61         9            3.0   141      8

# %% [markdown]
# ## 6. Pemodelan Machine Learning

# %% [markdown]
# ### 6.1. Membagi data train dan test

# %%
# Membuat variabel x untuk mencocokkan data user dan place menjadi satu value
x = df[['user', 'place']].values

# Membuat variabel y untuk membuat rating dari hasil
y = df['Place_Ratings'].apply(lambda x: (x - min_rating) / (max_rating - min_rating)).values

# Membagi menjadi 80% data train dan 20% data validasi
train_indices = int(0.8 * df.shape[0])
x_train, x_val, y_train, y_val = (
    x[:train_indices],
    x[train_indices:],
    y[:train_indices],
    y[train_indices:]
)

# %% [markdown]
# ### 6.2. Menyiapkan Model

# %% [markdown]
# #### Deklarasi Fungsi

# %%
def dict_encoder(col, data):
    unique_val = data[col].unique().tolist()
    val_to_val_encoded = {x: i for i, x in enumerate(unique_val)}
    val_encoded_to_val = {i: x for i, x in enumerate(unique_val)}
    return val_to_val_encoded, val_encoded_to_val

def encode_data(df):
    user_to_user_encoded, user_encoded_to_user = dict_encoder('User_Id', df)
    df['user'] = df['User_Id'].map(user_to_user_encoded)

    place_to_place_encoded, place_encoded_to_place = dict_encoder('Place_Id', df)
    df['place'] = df['Place_Id'].map(place_to_place_encoded)

    return df, user_to_user_encoded, place_to_place_encoded

# %% [markdown]
# #### Membaca, Mengolah, dan Mempersiapkan Data:

# %%
# Membaca data dan melakukan encoding
df_encoded, user_to_user_encoded, place_to_place_encoded = encode_data(rating)

# Mendapatkan jumlah user dan place
num_users, num_places = len(user_to_user_encoded), len(place_to_place_encoded)

# Mengubah rating menjadi nilai float
df_encoded['Place_Ratings'] = df_encoded['Place_Ratings'].values.astype(np.float32)

# Mendapatkan nilai minimum dan maksimum rating
min_rating, max_rating = min(df_encoded['Place_Ratings']), max(df_encoded['Place_Ratings'])

# %% [markdown]
# #### Pembagian Data dan Persiapan untuk Pelatihan:

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import GaussianNoise, Dropout, BatchNormalization, Input, Embedding, Flatten, Concatenate, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Embedding, GaussianNoise, Flatten, Concatenate, Dense, BatchNormalization, Dropout
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.metrics import MeanSquaredError
from sklearn.model_selection import KFold
import numpy as np

def create_ncf_model(num_users, num_places, embedding_size=50):
    user_input = Input(shape=(1,), name='user_input')
    place_input = Input(shape=(1,), name='place_input')

    user_embedding = Embedding(input_dim=num_users, output_dim=embedding_size, name='user_embedding')(user_input)
    user_embedding = GaussianNoise(0.1)(user_embedding)

    place_embedding = Embedding(input_dim=num_places, output_dim=embedding_size, name='place_embedding')(place_input)
    place_embedding = GaussianNoise(0.1)(place_embedding)

    user_flatten = Flatten()(user_embedding)
    place_flatten = Flatten()(place_embedding)

    concat = Concatenate()([user_flatten, place_flatten])

    dense = Dense(128, activation='relu', kernel_regularizer=l1_l2(l1=1e-4, l2=1e-3))(concat)
    batch_norm = BatchNormalization()(dense)
    dropout = Dropout(0.4)(batch_norm)

    dense_2 = Dense(64, activation='relu', kernel_regularizer=l1_l2(l1=1e-4, l2=1e-3))(dropout)
    batch_norm_2 = BatchNormalization()(dense_2)
    dropout_2 = Dropout(0.4)(batch_norm_2)

    dense_3 = Dense(32, activation='relu', kernel_regularizer=l1_l2(l1=1e-4, l2=1e-3))(dropout_2)
    batch_norm_3 = BatchNormalization()(dense_3)
    dropout_3 = Dropout(0.4)(batch_norm_3)

    output = Dense(1, activation='sigmoid')(dropout_3)

    model = Model(inputs=[user_input, place_input], outputs=output)
    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=1e-3), metrics=[MeanSquaredError()])
    model.save('best_model.h5')  # Menyimpan model awal, namun ini tidak digunakan dalam K-Fold

    return model

# Implementasi K-Fold Cross-Validation
kfold = KFold(n_splits=5, shuffle=True, random_state=1)
fold_no = 1
mse_scores = []
best_models = []

for train, test in kfold.split(x, y):
    model = create_ncf_model(num_users, num_places, embedding_size=50)

    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)
    model_checkpoint = ModelCheckpoint(
        filepath=f'best_model_fold_{fold_no}.keras',
        monitor='val_loss',
        save_best_only=True
    )

    history = model.fit(
        [x[train, 0], x[train, 1]], y[train],
        batch_size=128,
        epochs=100,
        validation_data=([x[test, 0], x[test, 1]], y[test]),
        callbacks=[early_stopping, reduce_lr, model_checkpoint],
        verbose=1
    )

    # Load the best model from each fold and compile it
    best_model_fold = load_model(f'best_model_fold_{fold_no}.keras')
    best_model_fold.compile(optimizer=Adam(learning_rate=1e-3),
                            loss='mean_squared_error',
                            metrics=[MeanSquaredError()])
    best_models.append(best_model_fold)

    fold_no += 1

# Gabungkan semua model terbaik menjadi satu model
final_model = create_ncf_model(num_users, num_places, embedding_size=50)

# Set the trainable attribute to False for all layers to freeze them
for layer in final_model.layers:
    layer.trainable = False

# Transfer weights from best models
for fold_model in best_models:
    final_model.set_weights(fold_model.get_weights())

# Save the final model
final_model.save('final_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - loss: 0.6465 - mean_squared_error: 0.2049 - val_loss: 0.5526 - val_mean_squared_error: 0.1175 - learning_rate: 0.0010
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6169 - mean_squared_error: 0.1839 - val_loss: 0.5441 - val_mean_squared_error: 0.1175 - learning_rate: 0.0010
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6093 - mean_squared_error: 0.1848 - val_loss: 0.5359 - val_mean_squared_error: 0.1178 - learning_rate: 0.0010
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5889 - mean_squared_error: 0.1729 - val_loss: 0.5274 - val_mean_squared_error: 0.1178 - learning_rate: 0.0010
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5791 - mean_squared_error: 0.1716 - val_loss: 0.5188 - val_mean_squared_error: 0.1176 - learning_rate: 0.0010
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5711 - mean_squared_error: 0.1721 - val_loss: 0.5100 - val_mean_squared_error: 0.1174 - learning_rate: 0.0010
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5547 - mean_squared_error: 0.1641 - val_loss: 0.5017 - val_mean_squared_error: 0.1174 - learning_rate: 0.0010
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5420 - mean_squared_error: 0.1597 - val_loss: 0.4933 - val_mean_squared_error: 0.1174 - learning_rate: 0.0010
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5270 - mean_squared_error: 0.1531 - val_loss: 0.4850 - val_mean_squared_error: 0.1173 - learning_rate: 0.0010
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5224 - mean_squared_error: 0.1567 - val_loss: 0.4769 - val_mean_squared_error: 0.1173 - learning_rate: 0.0010
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5083 - mean_squared_error: 0.1508 - val_loss: 0.4687 - val_mean_squared_error: 0.1173 - learning_rate: 0.0010
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5075 - mean_squared_error: 0.1581 - val_loss: 0.4607 - val_mean_squared_error: 0.1173 - learning_rate: 0.0010
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4896 - mean_squared_error: 0.1482 - val_loss: 0.4530 - val_mean_squared_error: 0.1175 - learning_rate: 0.0010
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4867 - mean_squared_error: 0.1532 - val_loss: 0.4449 - val_mean_squared_error: 0.1173 - learning_rate: 0.0010
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4726 - mean_squared_error: 0.1470 - val_loss: 0.4370 - val_mean_squared_error: 0.1173 - learning_rate: 0.0010
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4618 - mean_squared_error: 0.1440 - val_loss: 0.4292 - val_mean_squared_error: 0.1172 - learning_rate: 0.0010
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4466 - mean_squared_error: 0.1366 - val_loss: 0.4215 - val_mean_squared_error: 0.1173 - learning_rate: 0.0010
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4408 - mean_squared_error: 0.1385 - val_loss: 0.4138 - val_mean_squared_error: 0.1173 - learning_rate: 0.0010
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4359 - mean_squared_error: 0.1412 - val_loss: 0.4062 - val_mean_squared_error: 0.1173 - learning_rate: 0.0010
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4219 - mean_squared_error: 0.1348 - val_loss: 0.3986 - val_mean_squared_error: 0.1172 - learning_rate: 0.0010
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4142 - mean_squared_error: 0.1347 - val_loss: 0.3911 - val_mean_squared_error: 0.1173 - learning_rate: 0.0010
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4021 - mean_squared_error: 0.1302 - val_loss: 0.3838 - val_mean_squared_error: 0.1174 - learning_rate: 0.0010
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3941 - mean_squared_error: 0.1295 - val_loss: 0.3765 - val_mean_squared_error: 0.1175 - learning_rate: 0.0010
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3881 - mean_squared_error: 0.1309 - val_loss: 0.3690 - val_mean_squared_error: 0.1174 - learning_rate: 0.0010
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3730 - mean_squared_error: 0.1232 - val_loss: 0.3619 - val_mean_squared_error: 0.1175 - learning_rate: 0.0010
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3668 - mean_squared_error: 0.1242 - val_loss: 0.3547 - val_mean_squared_error: 0.1175 - learning_rate: 0.0010
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3563 - mean_squared_error: 0.1208 - val_loss: 0.3479 - val_mean_squared_error: 0.1177 - learning_rate: 0.0010
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3589 - mean_squared_error: 0.1305 - val_loss: 0.3408 - val_mean_squared_error: 0.1176 - learning_rate: 0.0010
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3486 - mean_squared_error: 0.1271 - val_loss: 0.3341 - val_mean_squared_error: 0.1178 - learning_rate: 0.0010
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3403 - mean_squared_error: 0.1257 - val_loss: 0.3274 - val_mean_squared_error: 0.1179 - learning_rate: 0.0010
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3321 - mean_squared_error: 0.1242 - val_loss: 0.3208 - val_mean_squared_error: 0.1179 - learning_rate: 0.0010
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3246 - mean_squared_error: 0.1233 - val_loss: 0.3141 - val_mean_squared_error: 0.1179 - learning_rate: 0.0010
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3157 - mean_squared_error: 0.1211 - val_loss: 0.3076 - val_mean_squared_error: 0.1179 - learning_rate: 0.0010
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3087 - mean_squared_error: 0.1205 - val_loss: 0.3013 - val_mean_squared_error: 0.1179 - learning_rate: 0.0010
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3040 - mean_squared_error: 0.1222 - val_loss: 0.2949 - val_mean_squared_error: 0.1178 - learning_rate: 0.0010
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2925 - mean_squared_error: 0.1170 - val_loss: 0.2889 - val_mean_squared_error: 0.1180 - learning_rate: 0.0010
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2891 - mean_squared_error: 0.1197 - val_loss: 0.2831 - val_mean_squared_error: 0.1182 - learning_rate: 0.0010
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2821 - mean_squared_error: 0.1186 - val_loss: 0.2772 - val_mean_squared_error: 0.1182 - learning_rate: 0.0010
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2750 - mean_squared_error: 0.1175 - val_loss: 0.2717 - val_mean_squared_error: 0.1185 - learning_rate: 0.0010
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2710 - mean_squared_error: 0.1193 - val_loss: 0.2661 - val_mean_squared_error: 0.1187 - learning_rate: 0.0010
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2657 - mean_squared_error: 0.1196 - val_loss: 0.2607 - val_mean_squared_error: 0.1188 - learning_rate: 0.0010
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2569 - mean_squared_error: 0.1164 - val_loss: 0.2553 - val_mean_squared_error: 0.1188 - learning_rate: 0.0010
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2496 - mean_squared_error: 0.1145 - val_loss: 0.2502 - val_mean_squared_error: 0.1191 - learning_rate: 0.0010
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2381 - mean_squared_error: 0.1083 - val_loss: 0.2457 - val_mean_squared_error: 0.1198 - learning_rate: 0.0010
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2428 - mean_squared_error: 0.1181 - val_loss: 0.2410 - val_mean_squared_error: 0.1201 - learning_rate: 0.0010
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2337 - mean_squared_error: 0.1141 - val_loss: 0.2366 - val_mean_squared_error: 0.1206 - learning_rate: 0.0010
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2260 - mean_squared_error: 0.1112 - val_loss: 0.2317 - val_mean_squared_error: 0.1205 - learning_rate: 0.0010
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2198 - mean_squared_error: 0.1098 - val_loss: 0.2277 - val_mean_squared_error: 0.1212 - learning_rate: 0.0010
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2151 - mean_squared_error: 0.1097 - val_loss: 0.2240 - val_mean_squared_error: 0.1221 - learning_rate: 0.0010
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2110 - mean_squared_error: 0.1101 - val_loss: 0.2199 - val_mean_squared_error: 0.1224 - learning_rate: 0.0010
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2064 - mean_squared_error: 0.1100 - val_loss: 0.2157 - val_mean_squared_error: 0.1225 - learning_rate: 0.0010
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2019 - mean_squared_error: 0.1098 - val_loss: 0.2124 - val_mean_squared_error: 0.1234 - learning_rate: 0.0010
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2009 - mean_squared_error: 0.1129 - val_loss: 0.2088 - val_mean_squared_error: 0.1238 - learning_rate: 0.0010
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1926 - mean_squared_error: 0.1086 - val_loss: 0.2044 - val_mean_squared_error: 0.1233 - learning_rate: 0.0010
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1888 - mean_squared_error: 0.1087 - val_loss: 0.2006 - val_mean_squared_error: 0.1233 - learning_rate: 0.0010
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1837 - mean_squared_error: 0.1073 - val_loss: 0.1974 - val_mean_squared_error: 0.1238 - learning_rate: 0.0010
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1827 - mean_squared_error: 0.1100 - val_loss: 0.1935 - val_mean_squared_error: 0.1236 - learning_rate: 0.0010
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1757 - mean_squared_error: 0.1066 - val_loss: 0.1913 - val_mean_squared_error: 0.1248 - learning_rate: 0.0010
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1700 - mean_squared_error: 0.1043 - val_loss: 0.1890 - val_mean_squared_error: 0.1258 - learning_rate: 0.0010
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1658 - mean_squared_error: 0.1034 - val_loss: 0.1863 - val_mean_squared_error: 0.1263 - learning_rate: 0.0010
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1614 - mean_squared_error: 0.1022 - val_loss: 0.1829 - val_mean_squared_error: 0.1260 - learning_rate: 0.0010
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1557 - mean_squared_error: 0.0996 - val_loss: 0.1799 - val_mean_squared_error: 0.1260 - learning_rate: 0.0010
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1571 - mean_squared_error: 0.1040 - val_loss: 0.1764 - val_mean_squared_error: 0.1254 - learning_rate: 0.0010
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1550 - mean_squared_error: 0.1047 - val_loss: 0.1730 - val_mean_squared_error: 0.1247 - learning_rate: 0.0010
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1484 - mean_squared_error: 0.1008 - val_loss: 0.1696 - val_mean_squared_error: 0.1239 - learning_rate: 0.0010
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1508 - mean_squared_error: 0.1058 - val_loss: 0.1674 - val_mean_squared_error: 0.1243 - learning_rate: 0.0010
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1481 - mean_squared_error: 0.1057 - val_loss: 0.1655 - val_mean_squared_error: 0.1248 - learning_rate: 0.0010
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1416 - mean_squared_error: 0.1015 - val_loss: 0.1648 - val_mean_squared_error: 0.1264 - learning_rate: 0.0010
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1382 - mean_squared_error: 0.1004 - val_loss: 0.1625 - val_mean_squared_error: 0.1263 - learning_rate: 0.0010
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1356 - mean_squared_error: 0.0999 - val_loss: 0.1603 - val_mean_squared_error: 0.1261 - learning_rate: 0.0010
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1392 - mean_squared_error: 0.1055 - val_loss: 0.1584 - val_mean_squared_error: 0.1261 - learning_rate: 0.0010
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1344 - mean_squared_error: 0.1026 - val_loss: 0.1577 - val_mean_squared_error: 0.1273 - learning_rate: 0.0010
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1333 - mean_squared_error: 0.1034 - val_loss: 0.1550 - val_mean_squared_error: 0.1265 - learning_rate: 0.0010
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1280 - mean_squared_error: 0.0999 - val_loss: 0.1543 - val_mean_squared_error: 0.1275 - learning_rate: 0.0010
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1278 - mean_squared_error: 0.1014 - val_loss: 0.1534 - val_mean_squared_error: 0.1282 - learning_rate: 0.0010
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1245 - mean_squared_error: 0.0996 - val_loss: 0.1522 - val_mean_squared_error: 0.1284 - learning_rate: 0.0010
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1247 - mean_squared_error: 0.1012 - val_loss: 0.1496 - val_mean_squared_error: 0.1271 - learning_rate: 0.0010
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1270 - mean_squared_error: 0.1048 - val_loss: 0.1480 - val_mean_squared_error: 0.1268 - learning_rate: 0.0010
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1209 - mean_squared_error: 0.1001 - val_loss: 0.1468 - val_mean_squared_error: 0.1270 - learning_rate: 0.0010
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1213 - mean_squared_error: 0.1017 - val_loss: 0.1451 - val_mean_squared_error: 0.1263 - learning_rate: 0.0010
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1203 - mean_squared_error: 0.1017 - val_loss: 0.1442 - val_mean_squared_error: 0.1264 - learning_rate: 0.0010
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1195 - mean_squared_error: 0.1019 - val_loss: 0.1428 - val_mean_squared_error: 0.1260 - learning_rate: 0.0010
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1198 - mean_squared_error: 0.1032 - val_loss: 0.1431 - val_mean_squared_error: 0.1272 - learning_rate: 0.0010
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1145 - mean_squared_error: 0.0987 - val_loss: 0.1435 - val_mean_squared_error: 0.1283 - learning_rate: 0.0010
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1137 - mean_squared_error: 0.0987 - val_loss: 0.1439 - val_mean_squared_error: 0.1294 - learning_rate: 0.0010
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1110 - mean_squared_error: 0.0965 - val_loss: 0.1449 - val_mean_squared_error: 0.1307 - learning_rate: 2.0000e-04
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1162 - mean_squared_error: 0.1020 - val_loss: 0.1447 - val_mean_squared_error: 0.1307 - learning_rate: 2.0000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - loss: 0.6399 - mean_squared_error: 0.1990 - val_loss: 0.5558 - val_mean_squared_error: 0.1211 - learning_rate: 0.0010
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6263 - mean_squared_error: 0.1937 - val_loss: 0.5470 - val_mean_squared_error: 0.1208 - learning_rate: 0.0010
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6153 - mean_squared_error: 0.1913 - val_loss: 0.5386 - val_mean_squared_error: 0.1209 - learning_rate: 0.0010
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5947 - mean_squared_error: 0.1790 - val_loss: 0.5303 - val_mean_squared_error: 0.1209 - learning_rate: 0.0010
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5813 - mean_squared_error: 0.1740 - val_loss: 0.5221 - val_mean_squared_error: 0.1209 - learning_rate: 0.0010
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5696 - mean_squared_error: 0.1705 - val_loss: 0.5141 - val_mean_squared_error: 0.1211 - learning_rate: 0.0010
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5535 - mean_squared_error: 0.1624 - val_loss: 0.5062 - val_mean_squared_error: 0.1212 - learning_rate: 0.0010
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5491 - mean_squared_error: 0.1661 - val_loss: 0.4980 - val_mean_squared_error: 0.1211 - learning_rate: 0.0010
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5359 - mean_squared_error: 0.1609 - val_loss: 0.4898 - val_mean_squared_error: 0.1208 - learning_rate: 0.0010
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5199 - mean_squared_error: 0.1528 - val_loss: 0.4822 - val_mean_squared_error: 0.1211 - learning_rate: 0.0010
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5039 - mean_squared_error: 0.1447 - val_loss: 0.4743 - val_mean_squared_error: 0.1210 - learning_rate: 0.0010
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4940 - mean_squared_error: 0.1426 - val_loss: 0.4665 - val_mean_squared_error: 0.1211 - learning_rate: 0.0010
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4966 - mean_squared_error: 0.1531 - val_loss: 0.4583 - val_mean_squared_error: 0.1206 - learning_rate: 0.0010
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4853 - mean_squared_error: 0.1495 - val_loss: 0.4506 - val_mean_squared_error: 0.1206 - learning_rate: 0.0010
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4647 - mean_squared_error: 0.1365 - val_loss: 0.4432 - val_mean_squared_error: 0.1209 - learning_rate: 0.0010
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4574 - mean_squared_error: 0.1369 - val_loss: 0.4358 - val_mean_squared_error: 0.1210 - learning_rate: 0.0010
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4589 - mean_squared_error: 0.1460 - val_loss: 0.4282 - val_mean_squared_error: 0.1209 - learning_rate: 0.0010
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4424 - mean_squared_error: 0.1370 - val_loss: 0.4205 - val_mean_squared_error: 0.1208 - learning_rate: 0.0010
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4359 - mean_squared_error: 0.1379 - val_loss: 0.4131 - val_mean_squared_error: 0.1208 - learning_rate: 0.0010
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4290 - mean_squared_error: 0.1384 - val_loss: 0.4058 - val_mean_squared_error: 0.1208 - learning_rate: 0.0010
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4187 - mean_squared_error: 0.1355 - val_loss: 0.3984 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4033 - mean_squared_error: 0.1274 - val_loss: 0.3911 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3959 - mean_squared_error: 0.1272 - val_loss: 0.3839 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3895 - mean_squared_error: 0.1280 - val_loss: 0.3768 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3815 - mean_squared_error: 0.1271 - val_loss: 0.3697 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3723 - mean_squared_error: 0.1250 - val_loss: 0.3627 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3684 - mean_squared_error: 0.1281 - val_loss: 0.3558 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3618 - mean_squared_error: 0.1283 - val_loss: 0.3490 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3538 - mean_squared_error: 0.1272 - val_loss: 0.3422 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3508 - mean_squared_error: 0.1309 - val_loss: 0.3356 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3351 - mean_squared_error: 0.1218 - val_loss: 0.3291 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3302 - mean_squared_error: 0.1235 - val_loss: 0.3227 - val_mean_squared_error: 0.1208 - learning_rate: 0.0010
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3239 - mean_squared_error: 0.1236 - val_loss: 0.3162 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3136 - mean_squared_error: 0.1196 - val_loss: 0.3099 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3122 - mean_squared_error: 0.1246 - val_loss: 0.3038 - val_mean_squared_error: 0.1208 - learning_rate: 0.0010
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3024 - mean_squared_error: 0.1209 - val_loss: 0.2977 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2967 - mean_squared_error: 0.1212 - val_loss: 0.2917 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2879 - mean_squared_error: 0.1184 - val_loss: 0.2858 - val_mean_squared_error: 0.1208 - learning_rate: 0.0010
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2821 - mean_squared_error: 0.1184 - val_loss: 0.2801 - val_mean_squared_error: 0.1208 - learning_rate: 0.0010
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2747 - mean_squared_error: 0.1167 - val_loss: 0.2744 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2740 - mean_squared_error: 0.1217 - val_loss: 0.2689 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2650 - mean_squared_error: 0.1181 - val_loss: 0.2635 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2575 - mean_squared_error: 0.1160 - val_loss: 0.2583 - val_mean_squared_error: 0.1208 - learning_rate: 0.0010
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2521 - mean_squared_error: 0.1158 - val_loss: 0.2532 - val_mean_squared_error: 0.1208 - learning_rate: 0.0010
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2469 - mean_squared_error: 0.1158 - val_loss: 0.2483 - val_mean_squared_error: 0.1210 - learning_rate: 0.0010
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2425 - mean_squared_error: 0.1164 - val_loss: 0.2435 - val_mean_squared_error: 0.1211 - learning_rate: 0.0010
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2391 - mean_squared_error: 0.1179 - val_loss: 0.2388 - val_mean_squared_error: 0.1211 - learning_rate: 0.0010
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2304 - mean_squared_error: 0.1139 - val_loss: 0.2343 - val_mean_squared_error: 0.1213 - learning_rate: 0.0010
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2225 - mean_squared_error: 0.1106 - val_loss: 0.2300 - val_mean_squared_error: 0.1217 - learning_rate: 0.0010
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2196 - mean_squared_error: 0.1124 - val_loss: 0.2258 - val_mean_squared_error: 0.1219 - learning_rate: 0.0010
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2134 - mean_squared_error: 0.1105 - val_loss: 0.2220 - val_mean_squared_error: 0.1224 - learning_rate: 0.0010
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2086 - mean_squared_error: 0.1100 - val_loss: 0.2181 - val_mean_squared_error: 0.1226 - learning_rate: 0.0010
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2006 - mean_squared_error: 0.1061 - val_loss: 0.2145 - val_mean_squared_error: 0.1232 - learning_rate: 0.0010
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1969 - mean_squared_error: 0.1065 - val_loss: 0.2108 - val_mean_squared_error: 0.1235 - learning_rate: 0.0010
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1925 - mean_squared_error: 0.1061 - val_loss: 0.2074 - val_mean_squared_error: 0.1240 - learning_rate: 0.0010
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1897 - mean_squared_error: 0.1072 - val_loss: 0.2039 - val_mean_squared_error: 0.1243 - learning_rate: 0.0010
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1841 - mean_squared_error: 0.1053 - val_loss: 0.2008 - val_mean_squared_error: 0.1248 - learning_rate: 0.0010
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1818 - mean_squared_error: 0.1067 - val_loss: 0.1975 - val_mean_squared_error: 0.1250 - learning_rate: 0.0010
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1735 - mean_squared_error: 0.1019 - val_loss: 0.1934 - val_mean_squared_error: 0.1243 - learning_rate: 0.0010
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1760 - mean_squared_error: 0.1077 - val_loss: 0.1896 - val_mean_squared_error: 0.1239 - learning_rate: 0.0010
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1761 - mean_squared_error: 0.1112 - val_loss: 0.1865 - val_mean_squared_error: 0.1240 - learning_rate: 0.0010
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1691 - mean_squared_error: 0.1073 - val_loss: 0.1839 - val_mean_squared_error: 0.1245 - learning_rate: 0.0010
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1630 - mean_squared_error: 0.1043 - val_loss: 0.1819 - val_mean_squared_error: 0.1255 - learning_rate: 0.0010
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1596 - mean_squared_error: 0.1039 - val_loss: 0.1794 - val_mean_squared_error: 0.1259 - learning_rate: 0.0010
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1603 - mean_squared_error: 0.1075 - val_loss: 0.1755 - val_mean_squared_error: 0.1248 - learning_rate: 0.0010
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1521 - mean_squared_error: 0.1021 - val_loss: 0.1733 - val_mean_squared_error: 0.1253 - learning_rate: 0.0010
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1535 - mean_squared_error: 0.1061 - val_loss: 0.1711 - val_mean_squared_error: 0.1257 - learning_rate: 0.0010
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1496 - mean_squared_error: 0.1047 - val_loss: 0.1695 - val_mean_squared_error: 0.1265 - learning_rate: 0.0010
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1452 - mean_squared_error: 0.1027 - val_loss: 0.1675 - val_mean_squared_error: 0.1267 - learning_rate: 0.0010
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1392 - mean_squared_error: 0.0989 - val_loss: 0.1658 - val_mean_squared_error: 0.1271 - learning_rate: 0.0010
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1416 - mean_squared_error: 0.1034 - val_loss: 0.1633 - val_mean_squared_error: 0.1266 - learning_rate: 0.0010
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1400 - mean_squared_error: 0.1038 - val_loss: 0.1608 - val_mean_squared_error: 0.1261 - learning_rate: 0.0010
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1344 - mean_squared_error: 0.1001 - val_loss: 0.1598 - val_mean_squared_error: 0.1269 - learning_rate: 0.0010
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1353 - mean_squared_error: 0.1029 - val_loss: 0.1586 - val_mean_squared_error: 0.1275 - learning_rate: 0.0010
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1366 - mean_squared_error: 0.1060 - val_loss: 0.1558 - val_mean_squared_error: 0.1265 - learning_rate: 0.0010
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1307 - mean_squared_error: 0.1017 - val_loss: 0.1553 - val_mean_squared_error: 0.1275 - learning_rate: 0.0010
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1257 - mean_squared_error: 0.0983 - val_loss: 0.1536 - val_mean_squared_error: 0.1274 - learning_rate: 0.0010
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1247 - mean_squared_error: 0.0988 - val_loss: 0.1524 - val_mean_squared_error: 0.1277 - learning_rate: 0.0010
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1282 - mean_squared_error: 0.1037 - val_loss: 0.1510 - val_mean_squared_error: 0.1276 - learning_rate: 0.0010
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1251 - mean_squared_error: 0.1020 - val_loss: 0.1491 - val_mean_squared_error: 0.1270 - learning_rate: 0.0010
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1189 - mean_squared_error: 0.0970 - val_loss: 0.1481 - val_mean_squared_error: 0.1271 - learning_rate: 0.0010
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1181 - mean_squared_error: 0.0974 - val_loss: 0.1478 - val_mean_squared_error: 0.1278 - learning_rate: 0.0010
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1230 - mean_squared_error: 0.1032 - val_loss: 0.1463 - val_mean_squared_error: 0.1273 - learning_rate: 0.0010
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1190 - mean_squared_error: 0.1001 - val_loss: 0.1460 - val_mean_squared_error: 0.1279 - learning_rate: 0.0010
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1197 - mean_squared_error: 0.1018 - val_loss: 0.1450 - val_mean_squared_error: 0.1277 - learning_rate: 0.0010
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1172 - mean_squared_error: 0.1001 - val_loss: 0.1459 - val_mean_squared_error: 0.1294 - learning_rate: 0.0010
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1182 - mean_squared_error: 0.1019 - val_loss: 0.1442 - val_mean_squared_error: 0.1284 - learning_rate: 0.0010
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1132 - mean_squared_error: 0.0977 - val_loss: 0.1426 - val_mean_squared_error: 0.1275 - learning_rate: 0.0010
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1186 - mean_squared_error: 0.1036 - val_loss: 0.1437 - val_mean_squared_error: 0.1292 - learning_rate: 0.0010
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1144 - mean_squared_error: 0.0999 - val_loss: 0.1449 - val_mean_squared_error: 0.1308 - learning_rate: 0.0010
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1161 - mean_squared_error: 0.1021 - val_loss: 0.1435 - val_mean_squared_error: 0.1299 - learning_rate: 0.0010
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1150 - mean_squared_error: 0.1015 - val_loss: 0.1434 - val_mean_squared_error: 0.1300 - learning_rate: 2.0000e-04
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1161 - mean_squared_error: 0.1029 - val_loss: 0.1440 - val_mean_squared_error: 0.1310 - learning_rate: 2.0000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: 0.6295 - mean_squared_error: 0.1907 - val_loss: 0.5563 - val_mean_squared_error: 0.1239 - learning_rate: 0.0010
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6246 - mean_squared_error: 0.1943 - val_loss: 0.5484 - val_mean_squared_error: 0.1246 - learning_rate: 0.0010
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6076 - mean_squared_error: 0.1859 - val_loss: 0.5399 - val_mean_squared_error: 0.1247 - learning_rate: 0.0010
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5872 - mean_squared_error: 0.1740 - val_loss: 0.5313 - val_mean_squared_error: 0.1246 - learning_rate: 0.0010
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5770 - mean_squared_error: 0.1724 - val_loss: 0.5223 - val_mean_squared_error: 0.1242 - learning_rate: 0.0010
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5645 - mean_squared_error: 0.1685 - val_loss: 0.5130 - val_mean_squared_error: 0.1234 - learning_rate: 0.0010
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5528 - mean_squared_error: 0.1654 - val_loss: 0.5045 - val_mean_squared_error: 0.1235 - learning_rate: 0.0010
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5364 - mean_squared_error: 0.1574 - val_loss: 0.4967 - val_mean_squared_error: 0.1242 - learning_rate: 0.0010
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.5279 - mean_squared_error: 0.1574 - val_loss: 0.4887 - val_mean_squared_error: 0.1246 - learning_rate: 0.0010
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5150 - mean_squared_error: 0.1529 - val_loss: 0.4797 - val_mean_squared_error: 0.1239 - learning_rate: 0.0010
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.5128 - mean_squared_error: 0.1591 - val_loss: 0.4706 - val_mean_squared_error: 0.1232 - learning_rate: 0.0010
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.4909 - mean_squared_error: 0.1454 - val_loss: 0.4619 - val_mean_squared_error: 0.1227 - learning_rate: 0.0010
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.4819 - mean_squared_error: 0.1447 - val_loss: 0.4537 - val_mean_squared_error: 0.1227 - learning_rate: 0.0010
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4742 - mean_squared_error: 0.1451 - val_loss: 0.4458 - val_mean_squared_error: 0.1229 - learning_rate: 0.0010
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4609 - mean_squared_error: 0.1400 - val_loss: 0.4376 - val_mean_squared_error: 0.1228 - learning_rate: 0.0010
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4492 - mean_squared_error: 0.1363 - val_loss: 0.4296 - val_mean_squared_error: 0.1228 - learning_rate: 0.0010
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4427 - mean_squared_error: 0.1379 - val_loss: 0.4216 - val_mean_squared_error: 0.1227 - learning_rate: 0.0010
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4344 - mean_squared_error: 0.1375 - val_loss: 0.4137 - val_mean_squared_error: 0.1227 - learning_rate: 0.0010
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4234 - mean_squared_error: 0.1344 - val_loss: 0.4059 - val_mean_squared_error: 0.1227 - learning_rate: 0.0010
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4159 - mean_squared_error: 0.1346 - val_loss: 0.3981 - val_mean_squared_error: 0.1226 - learning_rate: 0.0010
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4044 - mean_squared_error: 0.1308 - val_loss: 0.3904 - val_mean_squared_error: 0.1226 - learning_rate: 0.0010
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3996 - mean_squared_error: 0.1336 - val_loss: 0.3829 - val_mean_squared_error: 0.1226 - learning_rate: 0.0010
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3876 - mean_squared_error: 0.1292 - val_loss: 0.3755 - val_mean_squared_error: 0.1226 - learning_rate: 0.0010
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3779 - mean_squared_error: 0.1269 - val_loss: 0.3682 - val_mean_squared_error: 0.1226 - learning_rate: 0.0010
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3697 - mean_squared_error: 0.1260 - val_loss: 0.3609 - val_mean_squared_error: 0.1226 - learning_rate: 0.0010
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3613 - mean_squared_error: 0.1248 - val_loss: 0.3537 - val_mean_squared_error: 0.1226 - learning_rate: 0.0010
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3577 - mean_squared_error: 0.1284 - val_loss: 0.3465 - val_mean_squared_error: 0.1226 - learning_rate: 0.0010
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3527 - mean_squared_error: 0.1305 - val_loss: 0.3395 - val_mean_squared_error: 0.1226 - learning_rate: 0.0010
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3363 - mean_squared_error: 0.1211 - val_loss: 0.3325 - val_mean_squared_error: 0.1225 - learning_rate: 0.0010
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3314 - mean_squared_error: 0.1231 - val_loss: 0.3257 - val_mean_squared_error: 0.1225 - learning_rate: 0.0010
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3261 - mean_squared_error: 0.1246 - val_loss: 0.3190 - val_mean_squared_error: 0.1225 - learning_rate: 0.0010
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3182 - mean_squared_error: 0.1234 - val_loss: 0.3124 - val_mean_squared_error: 0.1225 - learning_rate: 0.0010
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3072 - mean_squared_error: 0.1189 - val_loss: 0.3059 - val_mean_squared_error: 0.1225 - learning_rate: 0.0010
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3082 - mean_squared_error: 0.1263 - val_loss: 0.2995 - val_mean_squared_error: 0.1224 - learning_rate: 0.0010
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2928 - mean_squared_error: 0.1172 - val_loss: 0.2933 - val_mean_squared_error: 0.1224 - learning_rate: 0.0010
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2892 - mean_squared_error: 0.1198 - val_loss: 0.2872 - val_mean_squared_error: 0.1224 - learning_rate: 0.0010
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2877 - mean_squared_error: 0.1244 - val_loss: 0.2813 - val_mean_squared_error: 0.1225 - learning_rate: 0.0010
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2783 - mean_squared_error: 0.1210 - val_loss: 0.2754 - val_mean_squared_error: 0.1225 - learning_rate: 0.0010
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2707 - mean_squared_error: 0.1192 - val_loss: 0.2696 - val_mean_squared_error: 0.1224 - learning_rate: 0.0010
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2682 - mean_squared_error: 0.1224 - val_loss: 0.2640 - val_mean_squared_error: 0.1224 - learning_rate: 0.0010
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2600 - mean_squared_error: 0.1197 - val_loss: 0.2585 - val_mean_squared_error: 0.1223 - learning_rate: 0.0010
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2515 - mean_squared_error: 0.1167 - val_loss: 0.2531 - val_mean_squared_error: 0.1223 - learning_rate: 0.0010
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2504 - mean_squared_error: 0.1209 - val_loss: 0.2481 - val_mean_squared_error: 0.1225 - learning_rate: 0.0010
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2414 - mean_squared_error: 0.1171 - val_loss: 0.2430 - val_mean_squared_error: 0.1224 - learning_rate: 0.0010
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2318 - mean_squared_error: 0.1125 - val_loss: 0.2380 - val_mean_squared_error: 0.1224 - learning_rate: 0.0010
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2360 - mean_squared_error: 0.1216 - val_loss: 0.2330 - val_mean_squared_error: 0.1221 - learning_rate: 0.0010
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2233 - mean_squared_error: 0.1137 - val_loss: 0.2282 - val_mean_squared_error: 0.1220 - learning_rate: 0.0010
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2251 - mean_squared_error: 0.1201 - val_loss: 0.2236 - val_mean_squared_error: 0.1220 - learning_rate: 0.0010
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2132 - mean_squared_error: 0.1127 - val_loss: 0.2193 - val_mean_squared_error: 0.1221 - learning_rate: 0.0010
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2085 - mean_squared_error: 0.1123 - val_loss: 0.2150 - val_mean_squared_error: 0.1220 - learning_rate: 0.0010
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2059 - mean_squared_error: 0.1139 - val_loss: 0.2106 - val_mean_squared_error: 0.1217 - learning_rate: 0.0010
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2012 - mean_squared_error: 0.1133 - val_loss: 0.2068 - val_mean_squared_error: 0.1218 - learning_rate: 0.0010
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1968 - mean_squared_error: 0.1127 - val_loss: 0.2027 - val_mean_squared_error: 0.1216 - learning_rate: 0.0010
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1935 - mean_squared_error: 0.1133 - val_loss: 0.1990 - val_mean_squared_error: 0.1216 - learning_rate: 0.0010
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1897 - mean_squared_error: 0.1133 - val_loss: 0.1949 - val_mean_squared_error: 0.1212 - learning_rate: 0.0010
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.1814 - mean_squared_error: 0.1086 - val_loss: 0.1913 - val_mean_squared_error: 0.1212 - learning_rate: 0.0010
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1789 - mean_squared_error: 0.1096 - val_loss: 0.1880 - val_mean_squared_error: 0.1212 - learning_rate: 0.0010
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1783 - mean_squared_error: 0.1124 - val_loss: 0.1847 - val_mean_squared_error: 0.1212 - learning_rate: 0.0010
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1748 - mean_squared_error: 0.1121 - val_loss: 0.1816 - val_mean_squared_error: 0.1213 - learning_rate: 0.0010
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1663 - mean_squared_error: 0.1068 - val_loss: 0.1787 - val_mean_squared_error: 0.1215 - learning_rate: 0.0010
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1648 - mean_squared_error: 0.1083 - val_loss: 0.1759 - val_mean_squared_error: 0.1216 - learning_rate: 0.0010
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1570 - mean_squared_error: 0.1034 - val_loss: 0.1731 - val_mean_squared_error: 0.1216 - learning_rate: 0.0010
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1604 - mean_squared_error: 0.1096 - val_loss: 0.1700 - val_mean_squared_error: 0.1212 - learning_rate: 0.0010
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1565 - mean_squared_error: 0.1083 - val_loss: 0.1673 - val_mean_squared_error: 0.1211 - learning_rate: 0.0010
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1573 - mean_squared_error: 0.1118 - val_loss: 0.1648 - val_mean_squared_error: 0.1211 - learning_rate: 0.0010
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1491 - mean_squared_error: 0.1061 - val_loss: 0.1626 - val_mean_squared_error: 0.1214 - learning_rate: 0.0010
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1484 - mean_squared_error: 0.1078 - val_loss: 0.1600 - val_mean_squared_error: 0.1211 - learning_rate: 0.0010
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1443 - mean_squared_error: 0.1059 - val_loss: 0.1580 - val_mean_squared_error: 0.1212 - learning_rate: 0.0010
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1464 - mean_squared_error: 0.1101 - val_loss: 0.1558 - val_mean_squared_error: 0.1211 - learning_rate: 0.0010
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1389 - mean_squared_error: 0.1047 - val_loss: 0.1541 - val_mean_squared_error: 0.1214 - learning_rate: 0.0010
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1412 - mean_squared_error: 0.1089 - val_loss: 0.1526 - val_mean_squared_error: 0.1216 - learning_rate: 0.0010
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1345 - mean_squared_error: 0.1039 - val_loss: 0.1511 - val_mean_squared_error: 0.1218 - learning_rate: 0.0010
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1365 - mean_squared_error: 0.1076 - val_loss: 0.1492 - val_mean_squared_error: 0.1215 - learning_rate: 0.0010
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1348 - mean_squared_error: 0.1075 - val_loss: 0.1481 - val_mean_squared_error: 0.1219 - learning_rate: 0.0010
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1280 - mean_squared_error: 0.1022 - val_loss: 0.1471 - val_mean_squared_error: 0.1224 - learning_rate: 0.0010
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1290 - mean_squared_error: 0.1046 - val_loss: 0.1462 - val_mean_squared_error: 0.1228 - learning_rate: 0.0010
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1280 - mean_squared_error: 0.1050 - val_loss: 0.1451 - val_mean_squared_error: 0.1230 - learning_rate: 0.0010
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1296 - mean_squared_error: 0.1078 - val_loss: 0.1436 - val_mean_squared_error: 0.1227 - learning_rate: 0.0010
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1253 - mean_squared_error: 0.1047 - val_loss: 0.1420 - val_mean_squared_error: 0.1223 - learning_rate: 0.0010
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1222 - mean_squared_error: 0.1028 - val_loss: 0.1409 - val_mean_squared_error: 0.1224 - learning_rate: 0.0010
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1223 - mean_squared_error: 0.1040 - val_loss: 0.1409 - val_mean_squared_error: 0.1233 - learning_rate: 0.0010
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1225 - mean_squared_error: 0.1051 - val_loss: 0.1398 - val_mean_squared_error: 0.1230 - learning_rate: 0.0010
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1225 - mean_squared_error: 0.1058 - val_loss: 0.1388 - val_mean_squared_error: 0.1228 - learning_rate: 0.0010
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1168 - mean_squared_error: 0.1009 - val_loss: 0.1392 - val_mean_squared_error: 0.1238 - learning_rate: 0.0010
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1178 - mean_squared_error: 0.1025 - val_loss: 0.1388 - val_mean_squared_error: 0.1241 - learning_rate: 0.0010
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1148 - mean_squared_error: 0.1002 - val_loss: 0.1372 - val_mean_squared_error: 0.1231 - learning_rate: 0.0010
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1169 - mean_squared_error: 0.1030 - val_loss: 0.1370 - val_mean_squared_error: 0.1236 - learning_rate: 0.0010
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1173 - mean_squared_error: 0.1040 - val_loss: 0.1368 - val_mean_squared_error: 0.1239 - learning_rate: 0.0010
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1143 - mean_squared_error: 0.1016 - val_loss: 0.1363 - val_mean_squared_error: 0.1238 - learning_rate: 0.0010
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1169 - mean_squared_error: 0.1045 - val_loss: 0.1370 - val_mean_squared_error: 0.1249 - learning_rate: 0.0010
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1150 - mean_squared_error: 0.1030 - val_loss: 0.1359 - val_mean_squared_error: 0.1243 - learning_rate: 0.0010
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1112 - mean_squared_error: 0.0997 - val_loss: 0.1353 - val_mean_squared_error: 0.1241 - learning_rate: 0.0010
# Epoch 93/100
# ...
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5112 - mean_squared_error: 0.1552 - val_loss: 0.4724 - val_mean_squared_error: 0.1220 - learning_rate: 0.0010
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4931 - mean_squared_error: 0.1447 - val_loss: 0.4647 - val_mean_squared_error: 0.1219 - learning_rate: 0.0010
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4895 - mean_squared_error: 0.1484 - val_loss: 0.4575 - val_mean_squared_error: 0.1221 - learning_rate: 0.0010
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4757 - mean_squared_error: 0.1421 - val_loss: 0.4499 - val_mean_squared_error: 0.1218 - learning_rate: 0.0010
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4801 - mean_squared_error: 0.1538 - val_loss: 0.4428 - val_mean_squared_error: 0.1221 - learning_rate: 0.0010
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4684 - mean_squared_error: 0.1495 - val_loss: 0.4366 - val_mean_squared_error: 0.1231 - learning_rate: 0.0010
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4502 - mean_squared_error: 0.1385 - val_loss: 0.4296 - val_mean_squared_error: 0.1233 - learning_rate: 0.0010
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4445 - mean_squared_error: 0.1400 - val_loss: 0.4211 - val_mean_squared_error: 0.1220 - learning_rate: 0.0010
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4302 - mean_squared_error: 0.1329 - val_loss: 0.4131 - val_mean_squared_error: 0.1212 - learning_rate: 0.0010
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4276 - mean_squared_error: 0.1375 - val_loss: 0.4055 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4174 - mean_squared_error: 0.1343 - val_loss: 0.3984 - val_mean_squared_error: 0.1207 - learning_rate: 0.0010
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4120 - mean_squared_error: 0.1360 - val_loss: 0.3916 - val_mean_squared_error: 0.1208 - learning_rate: 0.0010
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3964 - mean_squared_error: 0.1274 - val_loss: 0.3846 - val_mean_squared_error: 0.1209 - learning_rate: 0.0010
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3937 - mean_squared_error: 0.1316 - val_loss: 0.3775 - val_mean_squared_error: 0.1206 - learning_rate: 0.0010
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3781 - mean_squared_error: 0.1229 - val_loss: 0.3705 - val_mean_squared_error: 0.1205 - learning_rate: 0.0010
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3758 - mean_squared_error: 0.1275 - val_loss: 0.3636 - val_mean_squared_error: 0.1204 - learning_rate: 0.0010
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3747 - mean_squared_error: 0.1332 - val_loss: 0.3565 - val_mean_squared_error: 0.1200 - learning_rate: 0.0010
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3576 - mean_squared_error: 0.1228 - val_loss: 0.3495 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3485 - mean_squared_error: 0.1203 - val_loss: 0.3429 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3421 - mean_squared_error: 0.1206 - val_loss: 0.3363 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3420 - mean_squared_error: 0.1270 - val_loss: 0.3299 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3306 - mean_squared_error: 0.1220 - val_loss: 0.3236 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3249 - mean_squared_error: 0.1226 - val_loss: 0.3173 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3158 - mean_squared_error: 0.1197 - val_loss: 0.3111 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3083 - mean_squared_error: 0.1185 - val_loss: 0.3049 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3025 - mean_squared_error: 0.1188 - val_loss: 0.2989 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3004 - mean_squared_error: 0.1227 - val_loss: 0.2930 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2934 - mean_squared_error: 0.1216 - val_loss: 0.2872 - val_mean_squared_error: 0.1198 - learning_rate: 0.0010
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2860 - mean_squared_error: 0.1199 - val_loss: 0.2815 - val_mean_squared_error: 0.1198 - learning_rate: 0.0010
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2802 - mean_squared_error: 0.1199 - val_loss: 0.2759 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2716 - mean_squared_error: 0.1168 - val_loss: 0.2704 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2670 - mean_squared_error: 0.1177 - val_loss: 0.2649 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2652 - mean_squared_error: 0.1213 - val_loss: 0.2597 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2523 - mean_squared_error: 0.1136 - val_loss: 0.2545 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2534 - mean_squared_error: 0.1198 - val_loss: 0.2492 - val_mean_squared_error: 0.1195 - learning_rate: 0.0010
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2460 - mean_squared_error: 0.1175 - val_loss: 0.2441 - val_mean_squared_error: 0.1193 - learning_rate: 0.0010
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.2403 - mean_squared_error: 0.1168 - val_loss: 0.2392 - val_mean_squared_error: 0.1193 - learning_rate: 0.0010
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.2343 - mean_squared_error: 0.1156 - val_loss: 0.2346 - val_mean_squared_error: 0.1194 - learning_rate: 0.0010
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2294 - mean_squared_error: 0.1154 - val_loss: 0.2301 - val_mean_squared_error: 0.1195 - learning_rate: 0.0010
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2275 - mean_squared_error: 0.1180 - val_loss: 0.2253 - val_mean_squared_error: 0.1193 - learning_rate: 0.0010
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2203 - mean_squared_error: 0.1153 - val_loss: 0.2208 - val_mean_squared_error: 0.1191 - learning_rate: 0.0010
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2138 - mean_squared_error: 0.1132 - val_loss: 0.2164 - val_mean_squared_error: 0.1190 - learning_rate: 0.0010
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2060 - mean_squared_error: 0.1097 - val_loss: 0.2121 - val_mean_squared_error: 0.1190 - learning_rate: 0.0010
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2011 - mean_squared_error: 0.1089 - val_loss: 0.2081 - val_mean_squared_error: 0.1190 - learning_rate: 0.0010
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1985 - mean_squared_error: 0.1104 - val_loss: 0.2040 - val_mean_squared_error: 0.1189 - learning_rate: 0.0010
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1943 - mean_squared_error: 0.1101 - val_loss: 0.2002 - val_mean_squared_error: 0.1189 - learning_rate: 0.0010
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1888 - mean_squared_error: 0.1083 - val_loss: 0.1966 - val_mean_squared_error: 0.1189 - learning_rate: 0.0010
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1831 - mean_squared_error: 0.1063 - val_loss: 0.1932 - val_mean_squared_error: 0.1191 - learning_rate: 0.0010
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1833 - mean_squared_error: 0.1100 - val_loss: 0.1898 - val_mean_squared_error: 0.1191 - learning_rate: 0.0010
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1759 - mean_squared_error: 0.1061 - val_loss: 0.1865 - val_mean_squared_error: 0.1192 - learning_rate: 0.0010
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1774 - mean_squared_error: 0.1108 - val_loss: 0.1832 - val_mean_squared_error: 0.1191 - learning_rate: 0.0010
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1706 - mean_squared_error: 0.1072 - val_loss: 0.1802 - val_mean_squared_error: 0.1192 - learning_rate: 0.0010
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1685 - mean_squared_error: 0.1082 - val_loss: 0.1772 - val_mean_squared_error: 0.1192 - learning_rate: 0.0010
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1675 - mean_squared_error: 0.1102 - val_loss: 0.1742 - val_mean_squared_error: 0.1191 - learning_rate: 0.0010
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1645 - mean_squared_error: 0.1102 - val_loss: 0.1715 - val_mean_squared_error: 0.1193 - learning_rate: 0.0010
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1568 - mean_squared_error: 0.1053 - val_loss: 0.1692 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1556 - mean_squared_error: 0.1068 - val_loss: 0.1668 - val_mean_squared_error: 0.1199 - learning_rate: 0.0010
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1500 - mean_squared_error: 0.1037 - val_loss: 0.1645 - val_mean_squared_error: 0.1201 - learning_rate: 0.0010
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1477 - mean_squared_error: 0.1038 - val_loss: 0.1619 - val_mean_squared_error: 0.1198 - learning_rate: 0.0010
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1473 - mean_squared_error: 0.1058 - val_loss: 0.1595 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1439 - mean_squared_error: 0.1047 - val_loss: 0.1572 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1427 - mean_squared_error: 0.1057 - val_loss: 0.1554 - val_mean_squared_error: 0.1200 - learning_rate: 0.0010
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1353 - mean_squared_error: 0.1004 - val_loss: 0.1540 - val_mean_squared_error: 0.1206 - learning_rate: 0.0010
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1363 - mean_squared_error: 0.1033 - val_loss: 0.1524 - val_mean_squared_error: 0.1208 - learning_rate: 0.0010
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1357 - mean_squared_error: 0.1046 - val_loss: 0.1503 - val_mean_squared_error: 0.1204 - learning_rate: 0.0010
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1352 - mean_squared_error: 0.1057 - val_loss: 0.1480 - val_mean_squared_error: 0.1197 - learning_rate: 0.0010
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1337 - mean_squared_error: 0.1059 - val_loss: 0.1466 - val_mean_squared_error: 0.1200 - learning_rate: 0.0010
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1303 - mean_squared_error: 0.1041 - val_loss: 0.1452 - val_mean_squared_error: 0.1201 - learning_rate: 0.0010
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1251 - mean_squared_error: 0.1003 - val_loss: 0.1439 - val_mean_squared_error: 0.1202 - learning_rate: 0.0010
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1268 - mean_squared_error: 0.1034 - val_loss: 0.1435 - val_mean_squared_error: 0.1210 - learning_rate: 0.0010
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1284 - mean_squared_error: 0.1061 - val_loss: 0.1430 - val_mean_squared_error: 0.1215 - learning_rate: 0.0010
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1263 - mean_squared_error: 0.1051 - val_loss: 0.1416 - val_mean_squared_error: 0.1212 - learning_rate: 0.0010
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1230 - mean_squared_error: 0.1030 - val_loss: 0.1417 - val_mean_squared_error: 0.1225 - learning_rate: 0.0010
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1194 - mean_squared_error: 0.1006 - val_loss: 0.1407 - val_mean_squared_error: 0.1226 - learning_rate: 0.0010
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1197 - mean_squared_error: 0.1018 - val_loss: 0.1398 - val_mean_squared_error: 0.1226 - learning_rate: 0.0010
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1214 - mean_squared_error: 0.1045 - val_loss: 0.1386 - val_mean_squared_error: 0.1224 - learning_rate: 0.0010
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1208 - mean_squared_error: 0.1048 - val_loss: 0.1380 - val_mean_squared_error: 0.1225 - learning_rate: 0.0010
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1179 - mean_squared_error: 0.1026 - val_loss: 0.1378 - val_mean_squared_error: 0.1230 - learning_rate: 0.0010
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1178 - mean_squared_error: 0.1033 - val_loss: 0.1384 - val_mean_squared_error: 0.1243 - learning_rate: 0.0010
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1169 - mean_squared_error: 0.1030 - val_loss: 0.1380 - val_mean_squared_error: 0.1247 - learning_rate: 0.0010
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1139 - mean_squared_error: 0.1007 - val_loss: 0.1373 - val_mean_squared_error: 0.1247 - learning_rate: 0.0010
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1136 - mean_squared_error: 0.1012 - val_loss: 0.1352 - val_mean_squared_error: 0.1232 - learning_rate: 0.0010
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1167 - mean_squared_error: 0.1048 - val_loss: 0.1352 - val_mean_squared_error: 0.1236 - learning_rate: 0.0010
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1149 - mean_squared_error: 0.1034 - val_loss: 0.1342 - val_mean_squared_error: 0.1230 - learning_rate: 0.0010
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1118 - mean_squared_error: 0.1007 - val_loss: 0.1347 - val_mean_squared_error: 0.1238 - learning_rate: 0.0010
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1128 - mean_squared_error: 0.1020 - val_loss: 0.1367 - val_mean_squared_error: 0.1261 - learning_rate: 0.0010
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1168 - mean_squared_error: 0.1064 - val_loss: 0.1349 - val_mean_squared_error: 0.1247 - learning_rate: 0.0010
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1127 - mean_squared_error: 0.1026 - val_loss: 0.1349 - val_mean_squared_error: 0.1249 - learning_rate: 2.0000e-04
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1123 - mean_squared_error: 0.1024 - val_loss: 0.1346 - val_mean_squared_error: 0.1248 - learning_rate: 2.0000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.compile(optimizer=Adam(learning_rate=1e-3), loss='MeanSquaredError', metrics=[MeanSquaredError])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-e3f0c0320127> in <cell line: 1>()
# ----> 1 model.compile(optimizer=Adam(learning_rate=1e-3), loss='MeanSquaredError', metrics=[MeanSquaredError])
#
# NameError: name 'MeanSquaredError' is not defined

# %% [markdown]
# #### Inisialisasi dan Pelatihan Model:

# %% [markdown]
# #### Visualisasi Hasil Pelatihan

# %%
# Visualisasi hasil training dan validasi
plt.plot(history.history['loss'], label='train_loss (MSE)')
plt.plot(history.history['val_loss'], label='val_loss (MSE)')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.show()

plt.plot(history.history['mean_squared_error'], label='train_MeanSquaredError')
plt.plot(history.history['val_mean_squared_error'], label='val_MeanSquaredError')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()

# %% [markdown]
# ## hasil rekomendasi untuk user

# %%
# Buat DataFrame baru yang berisi semua pasangan pengguna-tempat yang mungkin
all_users = np.array(list(user_to_user_encoded.values()))
all_places = np.array(list(place_to_place_encoded.values()))
all_user_place = np.array(np.meshgrid(all_users, all_places)).T.reshape(-1, 2)
df_all_user_place = pd.DataFrame(all_user_place, columns=['user', 'place'])

# Gunakan model yang sudah dilatih untuk membuat prediksi rating
predictions = model.predict([df_all_user_place['user'], df_all_user_place['place']])

# Tambahkan prediksi rating ke DataFrame
df_all_user_place['predicted_rating'] = predictions.flatten()

# Urutkan hasil prediksi berdasarkan rating tertinggi
df_recommendations = df_all_user_place.sort_values(by='predicted_rating', ascending=False)

# Tampilkan hasil rekomendasi dalam bentuk DataFrame
print(df_recommendations.head(10))
# Out:
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
#        user  place  predicted_rating
# 23388   224     92          0.784478
# 18916   181     92          0.783672
# 24740   237     92          0.772499
# 24220   232     92          0.772091
# 20164   193     92          0.768961
# 23356   224     60          0.767084
# 14860   142     92          0.766402
# 18884   181     60          0.766313
# 1756     16     92          0.765841
# 23386   224     90          0.764150

# %%
# Group the recommendations by place and sort them by predicted rating in descending order
grouped_recommendations = df_recommendations.groupby('place').apply(lambda x: x.sort_values(by='predicted_rating', ascending=False))

# Print the top 10 recommendations with the highest rating, considering only one recommendation per place
print("Top 10 Cultural Recommendations:")
seen_places = set()
recommendations_count = 0
for index, row in grouped_recommendations.iterrows():
    place_id = place_encoded_to_place[row['place']]
    if place_id not in seen_places:
        place_details = place[place['Place_Id'] == place_id]
        category = place_details['Category'].iloc[0]

        # Check if the place belongs to the 'Culture' category
        if category == 'Taman Hiburan':
            place_name = place_details['Place_Name'].iloc[0]
            price = place_details['Price'].iloc[0]
            rating = place_details['Rating'].iloc[0]

            print(f"Place ID: {place_id}")
            print(f"Place Name: {place_name}")
            print(f"Category: {category}")
            print(f"Price: {price}")
            print(f"Rating: {rating}")
            print("\n")

            seen_places.add(place_id)
            recommendations_count += 1

            if recommendations_count >= 10:
                break
# Out:
# Top 10 Cultural Recommendations:
# Place ID: 3
# Place Name: Dunia Fantasi
# Category: Taman Hiburan
# Price: 270000
# Rating: 4.6
#
#
# Place ID: 4
# Place Name: Taman Mini Indonesia Indah (TMII)
# Category: Taman Hiburan
# Price: 10000
# Rating: 4.5
#
#
# Place ID: 5
# Place Name: Atlantis Water Adventure
# Category: Taman Hiburan
# Price: 94000
# Rating: 4.5
#
#
# Place ID: 6
# Place Name: Taman Impian Jaya Ancol
# Category: Taman Hiburan
# Price: 25000
# Rating: 4.5
#
#
# Place ID: 8
# Place Name: Ocean Ecopark
# Category: Taman Hiburan
# Price: 180000
# Rating: 4.0
#
#
# Place ID: 19
# Place Name: Kidzania
# Category: Taman Hiburan
# Price: 185000
# Rating: 4.6
#
#
# Place ID: 85
# Place Name: Taman Pintar Yogyakarta
# Category: Taman Hiburan
# Price: 6000
# Rating: 4.5
#
#
# Place ID: 87
# Place Name: Sindu Kusuma Edupark (SKE)
# Category: Taman Hiburan
# Price: 20000
# Rating: 4.2
#
#
# Place ID: 90
# Place Name: Kampung Wisata Taman Sari
# Category: Taman Hiburan
# Price: 5000
# Rating: 4.6
#
#
# Place ID: 91
# Place Name: Situs Warungboto
# Category: Taman Hiburan
# Price: 0
# Rating: 4.4

# %%
import pandas as pd
import numpy as np

# Membaca data baru
new_user = pd.read_csv('new_user_data.csv')
new_rating = pd.read_csv('sample_ratings.csv')

# Menampilkan beberapa baris pertama dari data baru untuk memastikan terbaca dengan benar
print(new_user.head())
print(new_rating.head())

# Menamakan ulang kolom untuk konsistensi jika diperlukan
new_rating.rename(columns={'place_id': 'Place_Id', 'user_id': 'User_Id', 'rating': 'Place_Ratings'}, inplace=True)

# Menggabungkan data rating baru dengan data tempat untuk mendapatkan informasi lengkap tempat
new_rating_merged = pd.merge(new_rating, place, on='Place_Id', how='left')

# Menampilkan beberapa baris pertama dari data yang digabungkan untuk memastikan penggabungan benar
print(new_rating_merged.head())

# Menggabungkan data baru dengan user data sebelumnya
new_user_encoded = new_user.copy()
new_user_encoded['user'] = new_user_encoded['User_Id'].map(user_to_user_encoded)

# Lakukan encoding pada User_Id dan Place_Id untuk data rating baru
new_rating_merged['user'] = new_rating_merged['User_Id'].map(user_to_user_encoded)
new_rating_merged['place'] = new_rating_merged['Place_Id'].map(place_to_place_encoded)

# Menghapus baris dengan nilai NaN akibat Place_Id atau User_Id yang tidak ada dalam dictionary
new_rating_merged = new_rating_merged.dropna(subset=['user', 'place'])

# Melakukan prediksi dengan model
predictions = model.predict([new_rating_merged['user'], new_rating_merged['place']])

# Menambahkan hasil prediksi ke DataFrame
new_rating_merged['predicted_rating'] = predictions.flatten()

# Menampilkan hasil prediksi
print(new_rating_merged[['User_Id', 'Place_Id', 'Place_Name', 'Category', 'predicted_rating']])
# Out:
#    User_Id                     Location  Age
# 0        1  Yogyakarta, D.I. Yogyakarta   54
# 1        2           Malang, Jawa Timur   42
# 2        3              Cilegon, Banten   29
# 3        4           Bekasi, Jawa Barat   15
# 4        5           Bekasi, Jawa Barat   44
#    place_id  user_id  rating
# 0         1      101     4.5
# 1         2      102     3.8
# 2         3      103     4.2
# 3         4      104     5.0
# 4         5      105     4.7
#    Place_Id  User_Id  Place_Ratings                         Place_Name  \
# 0         1      101            4.5                   Monumen Nasional
# 1         2      102            3.8                           Kota Tua
# 2         3      103            4.2                      Dunia Fantasi
# 3         4      104            5.0  Taman Mini Indonesia Indah (TMII)
# 4         5      105            4.7           Atlantis Water Adventure
#
#                                          Description       Category     City  \
# 0  Monumen Nasional atau yang populer disingkat d...         Budaya  Jakarta
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...         Budaya  Jakarta
# 2  Dunia Fantasi atau disebut juga Dufan adalah t...  Taman Hiburan  Jakarta
# 3  Taman Mini Indonesia Indah merupakan suatu kaw...  Taman Hiburan  Jakarta
# 4  Atlantis Water Adventure atau dikenal dengan A...  Taman Hiburan  Jakarta
#
#     Price  Rating                                       Coordinate       Lat  \
# 0   20000     4.6          {'lat': -6.1753924, 'lng': 106.8271528} -6.175392
# 1       0     4.6  {'lat': -6.137644799999999, 'lng': 106.8171245} -6.137645
# 2  270000     4.6  {'lat': -6.125312399999999, 'lng': 106.8335377} -6.125312
# 3   10000     4.5  {'lat': -6.302445899999999, 'lng': 106.8951559} -6.302446
# 4   94000     4.5             {'lat': -6.12419, 'lng': 106.839134} -6.124190
#
#          Long
# 0  106.827153
# 1  106.817125
# 2  106.833538
# 3  106.895156
# 4  106.839134
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
#    User_Id  Place_Id                         Place_Name       Category  \
# 0      101         1                   Monumen Nasional         Budaya
# 1      102         2                           Kota Tua         Budaya
# 2      103         3                      Dunia Fantasi  Taman Hiburan
# 3      104         4  Taman Mini Indonesia Indah (TMII)  Taman Hiburan
# 4      105         5           Atlantis Water Adventure  Taman Hiburan
# 5      106         6            Taman Impian Jaya Ancol  Taman Hiburan
# 6      107         7             Kebun Binatang Ragunan     Cagar Alam
# 7      108         8                      Ocean Ecopark  Taman Hiburan
# 8      109         9                   Pelabuhan Marina         Bahari
# 9      110        10                       Pulau Tidung         Bahari
#
#    predicted_rating
# 0          0.491927
# 1          0.520265
# 2          0.406123
# 3          0.484701
# 4          0.673014
# 5          0.461363
# 6          0.405394
# 7          0.633492
# 8          0.585006
# 9          0.413340

# %%
# Print the top 10 recommendations with the highest rating, considering only one recommendation per place
print("Top 10 Cultural Recommendations:")
seen_places = set()
recommendations_count = 0
for index, row in grouped_recommendations.iterrows():
    place_id = place_encoded_to_place[row['place']]
    if place_id not in seen_places:
        place_details = place[place['Place_Id'] == place_id]
        category = place_details['Category'].iloc[0]

        # Check if the place belongs to the 'Culture' category
        if category == 'Cagar Alam':
            place_name = place_details['Place_Name'].iloc[0]
            price = place_details['Price'].iloc[0]
            rating = place_details['Rating'].iloc[0]

            print(f"Place ID: {place_id}")
            print(f"Place Name: {place_name}")
            print(f"Category: {category}")
            print(f"Price: {price}")
            print(f"Rating: {rating}")
            print("\n")

            seen_places.add(place_id)
            recommendations_count += 1

            if recommendations_count >= 10:
                break
# Out:
# Top 10 Cultural Recommendations:
# Place ID: 7
# Place Name: Kebun Binatang Ragunan
# Category: Cagar Alam
# Price: 4000
# Rating: 4.5
#
#
# Place ID: 93
# Place Name: Gembira Loka Zoo
# Category: Cagar Alam
# Price: 60000
# Rating: 4.5
#
#
# Place ID: 211
# Place Name: GunungTangkuban perahu
# Category: Cagar Alam
# Price: 30000
# Rating: 4.5
#
#
# Place ID: 215
# Place Name: Taman Hutan Raya Ir. H. Djuanda
# Category: Cagar Alam
# Price: 15000
# Rating: 4.5
#
#
# Place ID: 217
# Place Name: Kebun Binatang Bandung
# Category: Cagar Alam
# Price: 20000
# Rating: 4.0
#
#
# Place ID: 218
# Place Name: Kawah Putih
# Category: Cagar Alam
# Price: 81000
# Rating: 4.5
#
#
# Place ID: 219
# Place Name: Tebing Karaton
# Category: Cagar Alam
# Price: 15000
# Rating: 4.5
#
#
# Place ID: 341
# Place Name: Hutan Wisata Tinjomoyo Semarang
# Category: Cagar Alam
# Price: 3000
# Rating: 4.3
#
#
# Place ID: 349
# Place Name: Wisata Mangrove Tapak
# Category: Cagar Alam
# Price: 5000
# Rating: 4.3
#
#
# Place ID: 355
# Place Name: Umbul Sidomukti
# Category: Cagar Alam
# Price: 75000
# Rating: 4.6

# %% [markdown]
# # save model

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.losses import MeanSquaredError
import os


# Memuat model dengan eksplisit menyertakan MeanSquaredError sebagai custom object
model = load_model('best_model.h5', custom_objects={'mean_squared_error': MeanSquaredError()})
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import joblib

joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']

# %%
place.to_csv('data/place_data.csv', index=False)

# %% [markdown]
# # API untuk Prediksi

# %%
import joblib

joblib.dump(user_to_user_encoded, 'user_to_user_encoded.pkl')
joblib.dump(place_to_place_encoded, 'place_to_place_encoded.pkl')
# Out:
# ['place_to_place_encoded.pkl']

# %%
import h5py

# Membuka file h5
file_path = 'best_model.h5'
with h5py.File(file_path, 'r') as f:
    # Menampilkan struktur file h5
    def print_structure(name, obj):
        print(name)
        for key, val in obj.attrs.items():
            print(f"    Attribute: {key}: {val}")

    f.visititems(print_structure)
# Out:
# model_weights
#     Attribute: backend: tensorflow
#     Attribute: keras_version: 3.3.3
#     Attribute: layer_names: ['user_input' 'place_input' 'user_embedding' 'place_embedding'
#  'gaussian_noise_36' 'gaussian_noise_37' 'flatten_36' 'flatten_37'
#  'concatenate_18' 'dense_72' 'batch_normalization_54' 'dropout_54'
#  'dense_73' 'batch_normalization_55' 'dropout_55' 'dense_74'
#  'batch_normalization_56' 'dropout_56' 'dense_75']
# model_weights/batch_normalization_54
#     Attribute: weight_names: ['batch_normalization_54/gamma' 'batch_normalization_54/beta'
#  'batch_normalization_54/moving_mean'
#  'batch_normalization_54/moving_variance']
# model_weights/batch_normalization_54/batch_normalization_54
# model_weights/batch_normalization_54/batch_normalization_54/beta
# model_weights/batch_normalization_54/batch_normalization_54/gamma
# model_weights/batch_normalization_54/batch_normalization_54/moving_mean
# model_weights/batch_normalization_54/batch_normalization_54/moving_variance
# model_weights/batch_normalization_55
#     Attribute: weight_names: ['batch_normalization_55/gamma' 'batch_normalization_55/beta'
#  'batch_normalization_55/moving_mean'
#  'batch_normalization_55/moving_variance']
# model_weights/batch_normalization_55/batch_normalization_55
# model_weights/batch_normalization_55/batch_normalization_55/beta
# model_weights/batch_normalization_55/batch_normalization_55/gamma
# model_weights/batch_normalization_55/batch_normalization_55/moving_mean
# model_weights/batch_normalization_55/batch_normalization_55/moving_variance
# model_weights/batch_normalization_56
#     Attribute: weight_names: ['batch_normalization_56/gamma' 'batch_normalization_56/beta'
#  'batch_normalization_56/moving_mean'
#  'batch_normalization_56/moving_variance']
# model_weights/batch_normalization_56/batch_normalization_56
# model_weights/batch_normalization_56/batch_normalization_56/beta
# model_weights/batch_normalization_56/batch_normalization_56/gamma
# model_weights/batch_normalization_56/batch_normalization_56/moving_mean
# model_weights/batch_normalization_56/batch_normalization_56/moving_variance
# model_weights/concatenate_18
#     Attribute: weight_names: []
# model_weights/dense_72
#     Attribute: weight_names: ['dense_72/kernel' 'dense_72/bias']
# model_weights/dense_72/dense_72
# model_weights/dense_72/dense_72/bias
# model_weights/dense_72/dense_72/kernel
# model_weights/dense_73
#     Attribute: weight_names: ['dense_73/kernel' 'dense_73/bias']
# model_weights/dense_73/dense_73
# model_weights/dense_73/dense_73/bias
# model_weights/dense_73/dense_73/kernel
# model_weights/dense_74
#     Attribute: weight_names: ['dense_74/kernel' 'dense_74/bias']
# model_weights/dense_74/dense_74
# model_weights/dense_74/dense_74/bias
# model_weights/dense_74/dense_74/kernel
# model_weights/dense_75
#     Attribute: weight_names: ['dense_75/kernel' 'dense_75/bias']
# model_weights/dense_75/dense_75
# model_weights/dense_75/dense_75/bias
# model_weights/dense_75/dense_75/kernel
# model_weights/dropout_54
#     Attribute: weight_names: []
# model_weights/dropout_55
#     Attribute: weight_names: []
# model_weights/dropout_56
#     Attribute: weight_names: []
# model_weights/flatten_36
#     Attribute: weight_names: []
# model_weights/flatten_37
#     Attribute: weight_names: []
# model_weights/gaussian_noise_36
#     Attribute: weight_names: []
# model_weights/gaussian_noise_37
#     Attribute: weight_names: []
# model_weights/place_embedding
#     Attribute: weight_names: ['place_embedding/embeddings']
# model_weights/place_embedding/place_embedding
# model_weights/place_embedding/place_embedding/embeddings
# model_weights/place_input
#     Attribute: weight_names: []
# model_weights/top_level_model_weights
#     Attribute: weight_names: []
# model_weights/user_embedding
#     Attribute: weight_names: ['user_embedding/embeddings']
# model_weights/user_embedding/user_embedding
# model_weights/user_embedding/user_embedding/embeddings
# model_weights/user_input
#     Attribute: weight_names: []
# optimizer_weights
#     Attribute: weight_names: ['adam/iteration' 'adam/learning_rate']
# optimizer_weights/adam
# optimizer_weights/adam/iteration
# optimizer_weights/adam/learning_rate

# %%
from flask import Flask, request, jsonify
from tensorflow.keras.models import load_model
import numpy as np
import pandas as pd


app = Flask(__name__)

# Muat model terlatih
model = tf.keras.models.load_model('best_model.h5')

# Muat dictionary encoding
user_to_user_encoded = joblib.load('user_to_user_encoded.pkl')
place_to_place_encoded = joblib.load('place_to_place_encoded.pkl')
place_to_index = {v: k for k, v in place_to_place_encoded.items()}  # Kebalikan dari place_to_place_encoded

@app.route('/recommend', methods=['GET'])
def recommend():
    user_id = int(request.args.get('user_id'))

    if user_id not in user_to_user_encoded:
        return jsonify({'error': 'User ID tidak ditemukan'}), 404

    user_encoded = user_to_user_encoded[user_id]
    all_places = np.array(list(place_to_place_encoded.values()))

    user_place_array = np.array([[user_encoded, place] for place in all_places])
    df_user_place = pd.DataFrame(user_place_array, columns=['user', 'place'])

    predictions = model.predict([df_user_place['user'], df_user_place['place']])
    df_user_place['predicted_rating'] = predictions.flatten()

    df_recommendations = df_user_place.sort_values(by='predicted_rating', ascending=False)
    top_recommendations = df_recommendations.head(10)

    recommended_places = [place_to_index[place] for place in top_recommendations['place'].values]

    return jsonify({'user_id': user_id, 'recommended_places': recommended_places})

if __name__ == '__main__':
    app.run(debug=True)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug: * Restarting with stat
