# %% [markdown]
# # Sistem Rekomendasi Destinasi Wisata Berbasis Collaborative Filtering
# <hr>

# %%
# !pip install -q kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !rm -rf data

# %%
! kaggle datasets list
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/__init__.py", line 7, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/api/kaggle_api_extended.py", line 398, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
! kaggle datasets download -d aprabowo/indonesia-tourism-destination
# Out:
# Dataset URL: https://www.kaggle.com/datasets/aprabowo/indonesia-tourism-destination
# License(s): copyright-authors
# Downloading indonesia-tourism-destination.zip to /content
#   0% 0.00/158k [00:00<?, ?B/s]
# 100% 158k/158k [00:00<00:00, 57.9MB/s]

# %%
import zipfile
import os

# %%
local_zip = 'indonesia-tourism-destination.zip'
target_extraction = '/content/data/'
file_check = "dataset"

try:
    if os.path.exists(os.path.join(target_extraction, file_check)):
        print("File Already Extracted")
    else:
        zip_ref = zipfile.ZipFile(local_zip, 'r')
        zip_ref.extractall(target_extraction)

except FileNotFoundError:
    print('Zip File Not Found!')

# %% [markdown]
# ## 1. Mengimpor Library Python yang Dibutuhkan

# %%
# Untuk pengolahan data
import pandas as pd
import numpy as np
from zipfile import ZipFile
from pathlib import Path

# Untuk visualisasi data
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
sns.set_palette('Set1')
sns.set()

# Untuk pemodelan
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Untuk menghilangkan warnings saat plotting seaborn
import warnings
warnings.filterwarnings('ignore')

# Untuk mengupload file
import os

# %% [markdown]
# ## 2. Menyiapkan Dataset yang digunakan

# %%
# Upload semua dataset yang dipakai
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# ## 3. Data Understanding

# %% [markdown]
# ### 3.1 Menyiapkan Data

# %%
# Menyimpan masing-masing dataset kedalam variabel

rating = pd.read_csv('data/tourism_rating.csv')
place = pd.read_csv('data/tourism_with_id.csv')
user = pd.read_csv('data/user.csv')

# %% [markdown]
# ### 3.2 Eksplorasi Fitur-fitur pada Data

# %% [markdown]
# #### 3.2.1. Data place

# %%
# Melihat gambaran data place

place.head(2)
# Out:
#    Place_Id        Place_Name  \
# 0         1  Monumen Nasional
# 1         2          Kota Tua
#
#                                          Description Category     City  Price  \
# 0  Monumen Nasional atau yang populer disingkat d...   Budaya  Jakarta  20000
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...   Budaya  Jakarta      0
#
#    Rating  Time_Minutes                                       Coordinate  \
# 0     4.6          15.0          {'lat': -6.1753924, 'lng': 106.8271528}
# 1     4.6          90.0  {'lat': -6.137644799999999, 'lng': 106.8171245}
#
#         Lat        Long  Unnamed: 11  Unnamed: 12
# 0 -6.175392  106.827153          NaN            1
# 1 -6.137645  106.817125          NaN            2

# %%
# Membuang kolom yang tidak dipakai

place = place.drop(['Unnamed: 11','Unnamed: 12'],axis=1)
place.head(2)
# Out:
#    Place_Id        Place_Name  \
# 0         1  Monumen Nasional
# 1         2          Kota Tua
#
#                                          Description Category     City  Price  \
# 0  Monumen Nasional atau yang populer disingkat d...   Budaya  Jakarta  20000
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...   Budaya  Jakarta      0
#
#    Rating  Time_Minutes                                       Coordinate  \
# 0     4.6          15.0          {'lat': -6.1753924, 'lng': 106.8271528}
# 1     4.6          90.0  {'lat': -6.137644799999999, 'lng': 106.8171245}
#
#         Lat        Long
# 0 -6.175392  106.827153
# 1 -6.137645  106.817125

# %%
place.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 437 entries, 0 to 436
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Place_Id      437 non-null    int64
#  1   Place_Name    437 non-null    object
#  2   Description   437 non-null    object
#  3   Category      437 non-null    object
#  4   City          437 non-null    object
#  5   Price         437 non-null    int64
#  6   Rating        437 non-null    float64
#  7   Time_Minutes  205 non-null    float64
#  8   Coordinate    437 non-null    object
#  9   Lat           437 non-null    float64
#  10  Long          437 non-null    float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 37.7+ KB

# %%
# Membuang kolom yang tidak dipakai

place = place.drop('Time_Minutes', axis=1)

# %%
df = pd.DataFrame(place)
print("Data sebelum diurutkan:")
print(df)
# Out:
# Data sebelum diurutkan:
#      Place_Id                                 Place_Name  \
# 0           1                           Monumen Nasional
# 1           2                                   Kota Tua
# 2           3                              Dunia Fantasi
# 3           4          Taman Mini Indonesia Indah (TMII)
# 4           5                   Atlantis Water Adventure
# ..        ...                                        ...
# 432       433                        Museum Mpu Tantular
# 433       434                              Taman Bungkul
# 434       435           Taman Air Mancur Menari Kenjeran
# 435       436               Taman Flora Bratang Surabaya
# 436       437  Gereja Perawan Maria Tak Berdosa Surabaya
#
#                                            Description       Category  \
# 0    Monumen Nasional atau yang populer disingkat d...         Budaya
# 1    Kota tua di Jakarta, yang juga bernama Kota Tu...         Budaya
# 2    Dunia Fantasi atau disebut juga Dufan adalah t...  Taman Hiburan
# 3    Taman Mini Indonesia Indah merupakan suatu kaw...  Taman Hiburan
# 4    Atlantis Water Adventure atau dikenal dengan A...  Taman Hiburan
# ..                                                 ...            ...
# 432  Museum Negeri Mpu Tantular adalah sebuah museu...         Budaya
# 433  Taman Bungkul adalah taman wisata kota yang te...  Taman Hiburan
# 434  Air mancur menari atau dancing fountain juga a...  Taman Hiburan
# 435  Taman Flora adalah salah satu taman kota di Su...  Taman Hiburan
# 436  Gereja Katolik Kelahiran Santa Perawan Maria m...  Tempat Ibadah
#
#          City   Price  Rating  \
# 0     Jakarta   20000     4.6
# 1     Jakarta       0     4.6
# 2     Jakarta  270000     4.6
# 3     Jakarta   10000     4.5
# 4     Jakarta   94000     4.5
# ..        ...     ...     ...
# 432  Surabaya    2000     4.4
# 433  Surabaya       0     4.6
# 434  Surabaya       0     4.4
# 435  Surabaya       0     4.6
# 436  Surabaya   10000     4.8
#
#                                           Coordinate       Lat        Long
# 0            {'lat': -6.1753924, 'lng': 106.8271528} -6.175392  106.827153
# 1    {'lat': -6.137644799999999, 'lng': 106.8171245} -6.137645  106.817125
# 2    {'lat': -6.125312399999999, 'lng': 106.8335377} -6.125312  106.833538
# 3    {'lat': -6.302445899999999, 'lng': 106.8951559} -6.302446  106.895156
# 4               {'lat': -6.12419, 'lng': 106.839134} -6.124190  106.839134
# ..                                               ...       ...         ...
# 432          {'lat': -7.4338593, 'lng': 112.7199058} -7.433859  112.719906
# 433  {'lat': -7.291346799999999, 'lng': 112.7398218} -7.291347  112.739822
# 434          {'lat': -7.2752955, 'lng': 112.7549381} -7.275296  112.754938
# 435  {'lat': -7.294330299999999, 'lng': 112.7617534} -7.294330  112.761753
# 436          {'lat': -7.2420758, 'lng': 112.7368158} -7.242076  112.736816
#
# [437 rows x 10 columns]

# %%
# Memfilter data berdasarkan rentang ID 1-20
# Memfilter data berdasarkan rentang ID 1-20
filter1 = df[(df['Place_Id'] >= 1) & (df['Place_Id'] <= 20)]

# Memfilter data berdasarkan rentang ID 85-105
filter2 = df[(df['Place_Id'] >= 85) & (df['Place_Id'] <= 105)]

# Memfilter data berdasarkan rentang ID 211-231
filter3 = df[(df['Place_Id'] >= 211) & (df['Place_Id'] <= 231)]

# Memfilter data berdasarkan rentang ID 335-355
filter4 = df[(df['Place_Id'] >= 335) & (df['Place_Id'] <= 355)]

# Memfilter data berdasarkan rentang ID 392-412
filter5 = df[(df['Place_Id'] >= 392) & (df['Place_Id'] <= 412)]

# Menggabungkan hasil filter
filtered_df = pd.concat([filter1, filter2, filter3, filter4, filter5])


# Mengurutkan dataset yang sudah difilter berdasarkan kolom 'ID'
place = filtered_df.sort_values(by='Place_Id')

# %%
# Menampilkan data setelah diurutkan
print("\nData setelah diurutkan:")
print(place)
# Out:
# Data setelah diurutkan:
#      Place_Id                         Place_Name  \
# 0           1                   Monumen Nasional
# 1           2                           Kota Tua
# 2           3                      Dunia Fantasi
# 3           4  Taman Mini Indonesia Indah (TMII)
# 4           5           Atlantis Water Adventure
# ..        ...                                ...
# 407       408            Kebun Binatang Surabaya
# 408       409                        Rumah Batik
# 409       410                  Ciputra Waterpark
# 410       411          Masjid Muhammad Cheng Hoo
# 411       412           Masjid Nasional Al-Akbar
#
#                                            Description       Category  \
# 0    Monumen Nasional atau yang populer disingkat d...         Budaya
# 1    Kota tua di Jakarta, yang juga bernama Kota Tu...         Budaya
# 2    Dunia Fantasi atau disebut juga Dufan adalah t...  Taman Hiburan
# 3    Taman Mini Indonesia Indah merupakan suatu kaw...  Taman Hiburan
# 4    Atlantis Water Adventure atau dikenal dengan A...  Taman Hiburan
# ..                                                 ...            ...
# 407  Kebun Binatang Surabaya (KBS) (Dialek Arekan: ...     Cagar Alam
# 408  Di rumah batik ini terdapat sekitar 2000 lemba...         Budaya
# 409  Ciputra Waterpark Surabaya – Bermain air di wa...  Taman Hiburan
# 410  Masjid Cheng Hoo Surabaya adalah Masjid bernua...  Tempat Ibadah
# 411  Masjid Nasional Al Akbar (atau biasa disebut M...  Tempat Ibadah
#
#          City   Price  Rating  \
# 0     Jakarta   20000     4.6
# 1     Jakarta       0     4.6
# 2     Jakarta  270000     4.6
# 3     Jakarta   10000     4.5
# 4     Jakarta   94000     4.5
# ..        ...     ...     ...
# 407  Surabaya   15000     4.3
# 408  Surabaya       0     4.5
# 409  Surabaya   95000     4.3
# 410  Surabaya       0     4.7
# 411  Surabaya       0     4.9
#
#                                           Coordinate       Lat        Long
# 0            {'lat': -6.1753924, 'lng': 106.8271528} -6.175392  106.827153
# 1    {'lat': -6.137644799999999, 'lng': 106.8171245} -6.137645  106.817125
# 2    {'lat': -6.125312399999999, 'lng': 106.8335377} -6.125312  106.833538
# 3    {'lat': -6.302445899999999, 'lng': 106.8951559} -6.302446  106.895156
# 4               {'lat': -6.12419, 'lng': 106.839134} -6.124190  106.839134
# ..                                               ...       ...         ...
# 407  {'lat': -7.295954599999999, 'lng': 112.7366094} -7.295955  112.736609
# 408   {'lat': -7.278735999999999, 'lng': 112.718453} -7.278736  112.718453
# 409          {'lat': -7.2861707, 'lng': 112.6333338} -7.286171  112.633334
# 410  {'lat': -7.252275399999999, 'lng': 112.7468796} -7.252275  112.746880
# 411  {'lat': -7.336614099999998, 'lng': 112.7151806} -7.336614  112.715181
#
# [104 rows x 10 columns]

# %% [markdown]
# ## Data Category

# %% [markdown]
# #### 3.2.2. Data rating

# %%
df_user = pd.DataFrame(user)

# Fungsi untuk menduplikasi dan membuat variasi data
def create_variation(df_user, n):
    dfs = [df_user.copy() for _ in range(n)]
    for i, df_var in enumerate(dfs):
        df_var['User_Id'] += i * len(df_user)  # Mengubah User_Id
    return pd.concat(dfs, ignore_index=True)

# Menduplikasi dan membuat variasi pada data
df_varied = create_variation(df_user, 3)  # 3 adalah jumlah variasi

print(df_varied)
# Out:
#      User_Id                     Location  Age
# 0          1        Semarang, Jawa Tengah   20
# 1          2           Bekasi, Jawa Barat   21
# 2          3          Cirebon, Jawa Barat   23
# 3          4           Bekasi, Jawa Barat   21
# 4          5    Lampung, Sumatera Selatan   20
# ..       ...                          ...  ...
# 895      896    Lampung, Sumatera Selatan   31
# 896      897  Palembang, Sumatera Selatan   39
# 897      898            Bogor, Jawa Barat   38
# 898      899          Sragen, Jawa Tengah   27
# 899      900         Ponorogo, Jawa Timur   26
#
# [900 rows x 3 columns]

# %%
#

# %%
# melihat gambaran data rating

rating.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0        1       179              3
# 1        1       344              2
# 2        1         5              5
# 3        1       373              3
# 4        1       101              4

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   User_Id        10000 non-null  int64
#  1   Place_Id       10000 non-null  int64
#  2   Place_Ratings  10000 non-null  int64
# dtypes: int64(3)
# memory usage: 234.5 KB

# %%
# Merubah data rating agar hanya berisi rating pada tempat wisata
rating = pd.merge(rating, place[['Place_Id']], how='right', on='Place_Id')
rating.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0       36         1              4
# 1       38         1              2
# 2       64         1              2
# 3       74         1              2
# 4       86         1              4

# %%
rating.shape
# Out:
# (2368, 3)

# %% [markdown]
# #### 3.2.3. Data user

# %%
# Melihat gambaran data user

user.head()
# Out:
#    User_Id                   Location  Age
# 0        1      Semarang, Jawa Tengah   20
# 1        2         Bekasi, Jawa Barat   21
# 2        3        Cirebon, Jawa Barat   23
# 3        4         Bekasi, Jawa Barat   21
# 4        5  Lampung, Sumatera Selatan   20

# %%
# Merubah data user agar hanya berisi user yang pernah megunjungi wisata

user = pd.merge(user, rating[['User_Id']], how='right', on='User_Id').sort_values('User_Id')
user.head()
# Out:
#       User_Id               Location  Age
# 83          1  Semarang, Jawa Tengah   20
# 415         1  Semarang, Jawa Tengah   20
# 1930        1  Semarang, Jawa Tengah   20
# 825         1  Semarang, Jawa Tengah   20
# 1637        1  Semarang, Jawa Tengah   20

# %%
# Melihat dataset user yang pernah memberi rating pada wisata

user.shape
# Out:
# (2368, 3)

# %% [markdown]
# ## 4. Eksplorasi Data

# %%
# Membuat dataframe berisi lokasi dengan jumlah rating terbanyak
top_10 = rating['Place_Id'].value_counts().reset_index()[0:10]
top_10.columns = ['Place_Id', 'count']  # Rename columns for easier access
top_10 = pd.merge(top_10, place[['Place_Id', 'Place_Name']], how='left', on='Place_Id')


# Membuat visualisasi wisata dengan jumlah rating terbanyak
plt.figure(figsize=(8, 5))
sns.barplot(x='count', y='Place_Name', data=top_10)
plt.title('Jumlah Tempat Wisata dengan Rating Terbanyak', pad=20)
plt.ylabel('Nama Lokasi')
plt.xlabel('Jumlah Rating')
plt.show()

# %%
# Membuat visualisasi jumlah kategori wisata

sns.countplot(y='Category', data=place)
plt.title('Perbandingan Jumlah Kategori Wisata ', pad=20)
plt.show()

# %%
# Membuat visualisasi distribusi usia user

plt.figure(figsize=(5,3))
sns.boxplot(user['Age']);
plt.title('Distribusi Usia User', pad=20)
plt.show()

# %%
# Membuat visualisasi distribusi harga masuk tempat wisata

plt.figure(figsize=(7,3))
sns.boxplot(place['Price'])
plt.title('Distribusi Harga Masuk Wisata ', pad=20)
plt.show()

# %%
# Memfilter asal kota dari user
askot = user['Location'].apply(lambda x : x.split(',')[0])

# Visualisasi asal kota dari user
plt.figure(figsize=(8,6))
sns.countplot(y=askot)
plt.title('Jumlah Asal Kota dari User')
plt.show()

# %% [markdown]
# ## 5. Persiapan Data untuk Pemodelan

# %% [markdown]
# ### 5.1. Membuat Salinan Data rating

# %%
# Membaca dataset untuk dilakukan encoding

df = rating.copy()
df.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0       36         1              4
# 1       38         1              2
# 2       64         1              2
# 3       74         1              2
# 4       86         1              4

# %% [markdown]
# ### 5.2. Melakukan Encoding

# %% [markdown]
# #### 5.2.1. Membuat Fungsi untuk Melakukan Encoding

# %%
def dict_encoder(col, data=df):

  # Mengubah kolom suatu dataframe menjadi list tanpa nilai yang sama
  unique_val = data[col].unique().tolist()

  # Melakukan encoding value kolom suatu dataframe ke angka
  val_to_val_encoded = {x: i for i, x in enumerate(unique_val)}

  # Melakukan proses encoding angka ke value dari kolom suatu dataframe
  val_encoded_to_val = {i: x for i, x in enumerate(unique_val)}
  return val_to_val_encoded, val_encoded_to_val

# %% [markdown]
# #### 5.2.2. Encoding dan Mapping Kolom User

# %%
# Encoding User_Id
user_to_user_encoded, user_encoded_to_user = dict_encoder('User_Id')

# Mapping User_Id ke dataframe
df['user'] = df['User_Id'].map(user_to_user_encoded)

# %% [markdown]
# #### 5.2.3. Encoding dan Mapping Kolom Place

# %%
# Encoding Place_Id
place_to_place_encoded, place_encoded_to_place = dict_encoder('Place_Id')

# Mapping Place_Id ke dataframe place
df['place'] = df['Place_Id'].map(place_to_place_encoded)
print(df)
# Out:
#       User_Id  Place_Id  Place_Ratings  user  place
# 0          36         1              4     0      0
# 1          38         1              2     1      0
# 2          64         1              2     2      0
# 3          74         1              2     3      0
# 4          86         1              4     4      0
# ...       ...       ...            ...   ...    ...
# 2363      191       412              3   292    103
# 2364      221       412              4   257    103
# 2365      226       412              5    87    103
# 2366      227       412              4    14    103
# 2367      262       412              1   134    103
#
# [2368 rows x 5 columns]

# %% [markdown]
# ### 5.3. Melihat Gambaran Data untuk Pemodelan

# %%
# Mendapatkan jumlah user dan place
num_users, num_place = len(user_to_user_encoded), len(place_to_place_encoded)

# Mengubah rating menjadi nilai float
df['Place_Ratings'] = df['Place_Ratings'].values.astype(np.float32)

# Mendapatkan nilai minimum dan maksimum rating
min_rating, max_rating = min(df['Place_Ratings']), max(df['Place_Ratings'])

print(f'Number of User: {num_users}, Number of Place: {num_place}, Min Rating: {min_rating}, Max Rating: {max_rating}')
# Out:
# Number of User: 300, Number of Place: 104, Min Rating: 1.0, Max Rating: 5.0

# %%
# Mengacak dataset
df = df.sample(frac=1, random_state=42)
df.head(2)
# Out:
#       User_Id  Place_Id  Place_Ratings  user  place
# 1094      289       217            2.0   242     47
# 188        61         9            3.0   141      8

# %% [markdown]
# ## 6. Pemodelan Machine Learning

# %% [markdown]
# ### 6.1. Membagi data train dan test

# %%
# Membuat variabel x untuk mencocokkan data user dan place menjadi satu value
x = df[['user', 'place']].values

# Membuat variabel y untuk membuat rating dari hasil
y = df['Place_Ratings'].apply(lambda x: (x - min_rating) / (max_rating - min_rating)).values

# Membagi menjadi 80% data train dan 20% data validasi
train_indices = int(0.8 * df.shape[0])
x_train, x_val, y_train, y_val = (
    x[:train_indices],
    x[train_indices:],
    y[:train_indices],
    y[train_indices:]
)

# %% [markdown]
# ### 6.2. Menyiapkan Model

# %% [markdown]
# #### Deklarasi Fungsi

# %%
def dict_encoder(col, data):
    unique_val = data[col].unique().tolist()
    val_to_val_encoded = {x: i for i, x in enumerate(unique_val)}
    val_encoded_to_val = {i: x for i, x in enumerate(unique_val)}
    return val_to_val_encoded, val_encoded_to_val

def encode_data(df):
    user_to_user_encoded, user_encoded_to_user = dict_encoder('User_Id', df)
    df['user'] = df['User_Id'].map(user_to_user_encoded)

    place_to_place_encoded, place_encoded_to_place = dict_encoder('Place_Id', df)
    df['place'] = df['Place_Id'].map(place_to_place_encoded)

    return df, user_to_user_encoded, place_to_place_encoded

# %% [markdown]
# #### Membaca, Mengolah, dan Mempersiapkan Data:

# %%
# Membaca data dan melakukan encoding
df_encoded, user_to_user_encoded, place_to_place_encoded = encode_data(rating)

# Mendapatkan jumlah user dan place
num_users, num_places = len(user_to_user_encoded), len(place_to_place_encoded)

# Mengubah rating menjadi nilai float
df_encoded['Place_Ratings'] = df_encoded['Place_Ratings'].values.astype(np.float32)

# Mendapatkan nilai minimum dan maksimum rating
min_rating, max_rating = min(df_encoded['Place_Ratings']), max(df_encoded['Place_Ratings'])

# %% [markdown]
# #### Pembagian Data dan Persiapan untuk Pelatihan:

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import GaussianNoise, Dropout, BatchNormalization, Input, Embedding, Flatten, Concatenate, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Embedding, GaussianNoise, Flatten, Concatenate, Dense, BatchNormalization, Dropout
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.model_selection import KFold
import numpy as np

def create_ncf_model(num_users, num_places, embedding_size=50):
    user_input = Input(shape=(1,), name='user_input')
    place_input = Input(shape=(1,), name='place_input')

    user_embedding = Embedding(input_dim=num_users, output_dim=embedding_size, name='user_embedding')(user_input)
    user_embedding = GaussianNoise(0.1)(user_embedding)

    place_embedding = Embedding(input_dim=num_places, output_dim=embedding_size, name='place_embedding')(place_input)
    place_embedding = GaussianNoise(0.1)(place_embedding)

    user_flatten = Flatten()(user_embedding)
    place_flatten = Flatten()(place_embedding)

    concat = Concatenate()([user_flatten, place_flatten])

    dense = Dense(128, activation='relu', kernel_regularizer=l1_l2(l1=1e-4, l2=1e-3))(concat)
    batch_norm = BatchNormalization()(dense)
    dropout = Dropout(0.4)(batch_norm)

    dense_2 = Dense(64, activation='relu', kernel_regularizer=l1_l2(l1=1e-4, l2=1e-3))(dropout)
    batch_norm_2 = BatchNormalization()(dense_2)
    dropout_2 = Dropout(0.4)(batch_norm_2)

    dense_3 = Dense(32, activation='relu', kernel_regularizer=l1_l2(l1=1e-4, l2=1e-3))(dropout_2)
    batch_norm_3 = BatchNormalization()(dense_3)
    dropout_3 = Dropout(0.4)(batch_norm_3)

    output = Dense(1, activation='sigmoid')(dropout_3)

    model = Model(inputs=[user_input, place_input], outputs=output)
    model.compile(loss='mse', optimizer=Adam(learning_rate=1e-3), metrics=['mse'])

    return model

# Assuming num_users and num_places are already defined
# model = create_ncf_model(num_users, num_places)
# model.summary()

# Implementasi K-Fold Cross-Validation
kfold = KFold(n_splits=5, shuffle=True, random_state=1)
fold_no = 1
mse_scores = []

best_models = []

for fold_no, (train, test) in enumerate(kfold.split(x, y), 1):
    model = create_ncf_model(num_users, num_places, embedding_size=50)

    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)
    model_checkpoint = ModelCheckpoint(
        filepath=f'best_model_fold_{fold_no}.h5',
        monitor='val_loss',
        save_best_only=True
    )

    history = model.fit(
        [x[train, 0], x[train, 1]], y[train],
        batch_size=128,
        epochs=100,
        validation_data=([x[test, 0], x[test, 1]], y[test]),
        callbacks=[early_stopping, reduce_lr, model_checkpoint],
        verbose=1
    )

    # Muat model terbaik dari setiap fold
    best_model_fold = load_model(f'best_model_fold_{fold_no}.h5')
    best_models.append(best_model_fold)

# Gabungkan semua model terbaik menjadi satu model
final_model = create_ncf_model(num_users, num_places, embedding_size=50)

# Set the trainable attribute to False for all layers to freeze them
for layer in final_model.layers:
    layer.trainable = False

# Transfer weights from best models
for fold_model in best_models:
    final_model.set_weights(fold_model.get_weights())

# Save the final model
final_model.save('best_model.h5')
# Out:
# Epoch 1/100
# 15/15 [==============================] - 12s 145ms/step - loss: 0.6420 - mse: 0.2006 - val_loss: 0.5538 - val_mse: 0.1174 - lr: 0.0010
# Epoch 2/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.6136 - mse: 0.1814 - val_loss: 0.5445 - val_mse: 0.1173 - lr: 0.0010
# Epoch 3/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.6066 - mse: 0.1837 - val_loss: 0.5353 - val_mse: 0.1174 - lr: 0.0010
# Epoch 4/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5907 - mse: 0.1769 - val_loss: 0.5263 - val_mse: 0.1174 - lr: 0.0010
# Epoch 5/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5795 - mse: 0.1747 - val_loss: 0.5173 - val_mse: 0.1173 - lr: 0.0010
# Epoch 6/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.5647 - mse: 0.1688 - val_loss: 0.5086 - val_mse: 0.1174 - lr: 0.0010
# Epoch 7/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.5520 - mse: 0.1648 - val_loss: 0.4999 - val_mse: 0.1174 - lr: 0.0010
# Epoch 8/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5414 - mse: 0.1628 - val_loss: 0.4915 - val_mse: 0.1175 - lr: 0.0010
# Epoch 9/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5289 - mse: 0.1589 - val_loss: 0.4830 - val_mse: 0.1176 - lr: 0.0010
# Epoch 10/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5118 - mse: 0.1502 - val_loss: 0.4745 - val_mse: 0.1175 - lr: 0.0010
# Epoch 11/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5062 - mse: 0.1531 - val_loss: 0.4661 - val_mse: 0.1176 - lr: 0.0010
# Epoch 12/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4943 - mse: 0.1496 - val_loss: 0.4578 - val_mse: 0.1175 - lr: 0.0010
# Epoch 13/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.4816 - mse: 0.1451 - val_loss: 0.4496 - val_mse: 0.1175 - lr: 0.0010
# Epoch 14/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.4797 - mse: 0.1514 - val_loss: 0.4416 - val_mse: 0.1177 - lr: 0.0010
# Epoch 15/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4645 - mse: 0.1444 - val_loss: 0.4336 - val_mse: 0.1178 - lr: 0.0010
# Epoch 16/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4516 - mse: 0.1395 - val_loss: 0.4257 - val_mse: 0.1179 - lr: 0.0010
# Epoch 17/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.4421 - mse: 0.1380 - val_loss: 0.4178 - val_mse: 0.1179 - lr: 0.0010
# Epoch 18/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.4340 - mse: 0.1378 - val_loss: 0.4098 - val_mse: 0.1178 - lr: 0.0010
# Epoch 19/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4218 - mse: 0.1334 - val_loss: 0.4020 - val_mse: 0.1178 - lr: 0.0010
# Epoch 20/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.4140 - mse: 0.1333 - val_loss: 0.3942 - val_mse: 0.1176 - lr: 0.0010
# Epoch 21/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4044 - mse: 0.1313 - val_loss: 0.3864 - val_mse: 0.1175 - lr: 0.0010
# Epoch 22/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3975 - mse: 0.1320 - val_loss: 0.3789 - val_mse: 0.1174 - lr: 0.0010
# Epoch 23/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3911 - mse: 0.1331 - val_loss: 0.3715 - val_mse: 0.1175 - lr: 0.0010
# Epoch 24/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.3809 - mse: 0.1302 - val_loss: 0.3641 - val_mse: 0.1174 - lr: 0.0010
# Epoch 25/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3703 - mse: 0.1269 - val_loss: 0.3570 - val_mse: 0.1175 - lr: 0.0010
# Epoch 26/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.3670 - mse: 0.1308 - val_loss: 0.3499 - val_mse: 0.1176 - lr: 0.0010
# Epoch 27/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3562 - mse: 0.1272 - val_loss: 0.3428 - val_mse: 0.1176 - lr: 0.0010
# Epoch 28/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3469 - mse: 0.1249 - val_loss: 0.3357 - val_mse: 0.1174 - lr: 0.0010
# Epoch 29/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3405 - mse: 0.1254 - val_loss: 0.3289 - val_mse: 0.1174 - lr: 0.0010
# Epoch 30/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3354 - mse: 0.1270 - val_loss: 0.3221 - val_mse: 0.1174 - lr: 0.0010
# Epoch 31/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.3259 - mse: 0.1242 - val_loss: 0.3155 - val_mse: 0.1174 - lr: 0.0010
# Epoch 32/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3182 - mse: 0.1232 - val_loss: 0.3089 - val_mse: 0.1174 - lr: 0.0010
# Epoch 33/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.3122 - mse: 0.1236 - val_loss: 0.3025 - val_mse: 0.1174 - lr: 0.0010
# Epoch 34/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.3038 - mse: 0.1216 - val_loss: 0.2962 - val_mse: 0.1174 - lr: 0.0010
# Epoch 35/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2973 - mse: 0.1214 - val_loss: 0.2900 - val_mse: 0.1174 - lr: 0.0010
# Epoch 36/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.2894 - mse: 0.1196 - val_loss: 0.2839 - val_mse: 0.1174 - lr: 0.0010
# Epoch 37/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2830 - mse: 0.1193 - val_loss: 0.2780 - val_mse: 0.1174 - lr: 0.0010
# Epoch 38/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2763 - mse: 0.1184 - val_loss: 0.2722 - val_mse: 0.1175 - lr: 0.0010
# Epoch 39/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2700 - mse: 0.1180 - val_loss: 0.2666 - val_mse: 0.1176 - lr: 0.0010
# Epoch 40/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2635 - mse: 0.1171 - val_loss: 0.2611 - val_mse: 0.1176 - lr: 0.0010
# Epoch 41/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2584 - mse: 0.1174 - val_loss: 0.2558 - val_mse: 0.1177 - lr: 0.0010
# Epoch 42/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2522 - mse: 0.1165 - val_loss: 0.2506 - val_mse: 0.1178 - lr: 0.0010
# Epoch 43/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2455 - mse: 0.1150 - val_loss: 0.2457 - val_mse: 0.1179 - lr: 0.0010
# Epoch 44/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.2399 - mse: 0.1145 - val_loss: 0.2409 - val_mse: 0.1182 - lr: 0.0010
# Epoch 45/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2336 - mse: 0.1131 - val_loss: 0.2362 - val_mse: 0.1184 - lr: 0.0010
# Epoch 46/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2285 - mse: 0.1129 - val_loss: 0.2317 - val_mse: 0.1186 - lr: 0.0010
# Epoch 47/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2219 - mse: 0.1111 - val_loss: 0.2274 - val_mse: 0.1190 - lr: 0.0010
# Epoch 48/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2185 - mse: 0.1123 - val_loss: 0.2231 - val_mse: 0.1192 - lr: 0.0010
# Epoch 49/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2125 - mse: 0.1107 - val_loss: 0.2189 - val_mse: 0.1195 - lr: 0.0010
# Epoch 50/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2075 - mse: 0.1100 - val_loss: 0.2150 - val_mse: 0.1198 - lr: 0.0010
# Epoch 51/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.2032 - mse: 0.1100 - val_loss: 0.2111 - val_mse: 0.1201 - lr: 0.0010
# Epoch 52/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1980 - mse: 0.1088 - val_loss: 0.2077 - val_mse: 0.1207 - lr: 0.0010
# Epoch 53/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1924 - mse: 0.1072 - val_loss: 0.2045 - val_mse: 0.1214 - lr: 0.0010
# Epoch 54/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1893 - mse: 0.1080 - val_loss: 0.2012 - val_mse: 0.1220 - lr: 0.0010
# Epoch 55/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1862 - mse: 0.1088 - val_loss: 0.1970 - val_mse: 0.1215 - lr: 0.0010
# Epoch 56/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1807 - mse: 0.1069 - val_loss: 0.1936 - val_mse: 0.1217 - lr: 0.0010
# Epoch 57/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1741 - mse: 0.1039 - val_loss: 0.1909 - val_mse: 0.1226 - lr: 0.0010
# Epoch 58/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1720 - mse: 0.1052 - val_loss: 0.1883 - val_mse: 0.1232 - lr: 0.0010
# Epoch 59/100
# 15/15 [==============================] - 0s 21ms/step - loss: 0.1686 - mse: 0.1050 - val_loss: 0.1852 - val_mse: 0.1233 - lr: 0.0010
# Epoch 60/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1656 - mse: 0.1051 - val_loss: 0.1818 - val_mse: 0.1230 - lr: 0.0010
# Epoch 61/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1602 - mse: 0.1028 - val_loss: 0.1792 - val_mse: 0.1234 - lr: 0.0010
# Epoch 62/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.1578 - mse: 0.1033 - val_loss: 0.1770 - val_mse: 0.1240 - lr: 0.0010
# Epoch 63/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1552 - mse: 0.1035 - val_loss: 0.1739 - val_mse: 0.1237 - lr: 0.0010
# Epoch 64/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.1517 - mse: 0.1027 - val_loss: 0.1712 - val_mse: 0.1236 - lr: 0.0010
# Epoch 65/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.1512 - mse: 0.1048 - val_loss: 0.1682 - val_mse: 0.1231 - lr: 0.0010
# Epoch 66/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1462 - mse: 0.1023 - val_loss: 0.1659 - val_mse: 0.1232 - lr: 0.0010
# Epoch 67/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1451 - mse: 0.1034 - val_loss: 0.1647 - val_mse: 0.1244 - lr: 0.0010
# Epoch 68/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.1430 - mse: 0.1037 - val_loss: 0.1639 - val_mse: 0.1258 - lr: 0.0010
# Epoch 69/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.1400 - mse: 0.1029 - val_loss: 0.1613 - val_mse: 0.1253 - lr: 0.0010
# Epoch 70/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1364 - mse: 0.1014 - val_loss: 0.1579 - val_mse: 0.1240 - lr: 0.0010
# Epoch 71/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.1358 - mse: 0.1027 - val_loss: 0.1573 - val_mse: 0.1253 - lr: 0.0010
# Epoch 72/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.1331 - mse: 0.1019 - val_loss: 0.1553 - val_mse: 0.1251 - lr: 0.0010
# Epoch 73/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1306 - mse: 0.1011 - val_loss: 0.1539 - val_mse: 0.1253 - lr: 0.0010
# Epoch 74/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1298 - mse: 0.1019 - val_loss: 0.1521 - val_mse: 0.1251 - lr: 0.0010
# Epoch 75/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1276 - mse: 0.1012 - val_loss: 0.1507 - val_mse: 0.1251 - lr: 0.0010
# Epoch 76/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1272 - mse: 0.1022 - val_loss: 0.1498 - val_mse: 0.1256 - lr: 0.0010
# Epoch 77/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1241 - mse: 0.1005 - val_loss: 0.1496 - val_mse: 0.1266 - lr: 0.0010
# Epoch 78/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1235 - mse: 0.1011 - val_loss: 0.1474 - val_mse: 0.1256 - lr: 0.0010
# Epoch 79/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1228 - mse: 0.1016 - val_loss: 0.1450 - val_mse: 0.1243 - lr: 0.0010
# Epoch 80/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1204 - mse: 0.1002 - val_loss: 0.1478 - val_mse: 0.1281 - lr: 0.0010
# Epoch 81/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1210 - mse: 0.1018 - val_loss: 0.1484 - val_mse: 0.1296 - lr: 0.0010
# Epoch 82/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1192 - mse: 0.1008 - val_loss: 0.1449 - val_mse: 0.1269 - lr: 0.0010
# Epoch 83/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1190 - mse: 0.1012 - val_loss: 0.1457 - val_mse: 0.1280 - lr: 2.0000e-04
# Epoch 84/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1177 - mse: 0.1002 - val_loss: 0.1465 - val_mse: 0.1293 - lr: 2.0000e-04
# Epoch 85/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1170 - mse: 0.0999 - val_loss: 0.1473 - val_mse: 0.1304 - lr: 2.0000e-04
# Epoch 86/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1168 - mse: 0.0999 - val_loss: 0.1480 - val_mse: 0.1311 - lr: 4.0000e-05
# Epoch 87/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1192 - mse: 0.1024 - val_loss: 0.1484 - val_mse: 0.1317 - lr: 4.0000e-05
# Epoch 1/100
# 15/15 [==============================] - 3s 30ms/step - loss: 0.6611 - mse: 0.2246 - val_loss: 0.5568 - val_mse: 0.1244 - lr: 0.0010
# Epoch 2/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6492 - mse: 0.2201 - val_loss: 0.5586 - val_mse: 0.1335 - lr: 0.0010
# Epoch 3/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6265 - mse: 0.2049 - val_loss: 0.5597 - val_mse: 0.1420 - lr: 0.0010
# Epoch 4/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.6152 - mse: 0.2009 - val_loss: 0.5568 - val_mse: 0.1464 - lr: 0.0010
# Epoch 5/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6052 - mse: 0.1955 - val_loss: 0.5652 - val_mse: 0.1564 - lr: 2.0000e-04
# Epoch 6/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6027 - mse: 0.1945 - val_loss: 0.5727 - val_mse: 0.1653 - lr: 2.0000e-04
# Epoch 7/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.5976 - mse: 0.1910 - val_loss: 0.5783 - val_mse: 0.1725 - lr: 2.0000e-04
# Epoch 8/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6009 - mse: 0.1952 - val_loss: 0.5853 - val_mse: 0.1798 - lr: 4.0000e-05
# Epoch 9/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.5931 - mse: 0.1878 - val_loss: 0.5913 - val_mse: 0.1861 - lr: 4.0000e-05
# Epoch 1/100
# 15/15 [==============================] - 3s 70ms/step - loss: 0.6325 - mse: 0.1940 - val_loss: 0.5559 - val_mse: 0.1224 - lr: 0.0010
# Epoch 2/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.6107 - mse: 0.1814 - val_loss: 0.5469 - val_mse: 0.1226 - lr: 0.0010
# Epoch 3/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.6005 - mse: 0.1804 - val_loss: 0.5378 - val_mse: 0.1226 - lr: 0.0010
# Epoch 4/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5818 - mse: 0.1708 - val_loss: 0.5291 - val_mse: 0.1229 - lr: 0.0010
# Epoch 5/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5690 - mse: 0.1669 - val_loss: 0.5201 - val_mse: 0.1228 - lr: 0.0010
# Epoch 6/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.5574 - mse: 0.1642 - val_loss: 0.5115 - val_mse: 0.1231 - lr: 0.0010
# Epoch 7/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5412 - mse: 0.1568 - val_loss: 0.5026 - val_mse: 0.1230 - lr: 0.0010
# Epoch 8/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.5354 - mse: 0.1598 - val_loss: 0.4938 - val_mse: 0.1228 - lr: 0.0010
# Epoch 9/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.5268 - mse: 0.1598 - val_loss: 0.4854 - val_mse: 0.1230 - lr: 0.0010
# Epoch 10/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5093 - mse: 0.1508 - val_loss: 0.4766 - val_mse: 0.1226 - lr: 0.0010
# Epoch 11/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.4986 - mse: 0.1485 - val_loss: 0.4683 - val_mse: 0.1227 - lr: 0.0010
# Epoch 12/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.4897 - mse: 0.1480 - val_loss: 0.4601 - val_mse: 0.1228 - lr: 0.0010
# Epoch 13/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4776 - mse: 0.1441 - val_loss: 0.4518 - val_mse: 0.1228 - lr: 0.0010
# Epoch 14/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4676 - mse: 0.1423 - val_loss: 0.4437 - val_mse: 0.1229 - lr: 0.0010
# Epoch 15/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4578 - mse: 0.1407 - val_loss: 0.4356 - val_mse: 0.1229 - lr: 0.0010
# Epoch 16/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4436 - mse: 0.1346 - val_loss: 0.4277 - val_mse: 0.1229 - lr: 0.0010
# Epoch 17/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4407 - mse: 0.1396 - val_loss: 0.4199 - val_mse: 0.1231 - lr: 0.0010
# Epoch 18/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4287 - mse: 0.1355 - val_loss: 0.4120 - val_mse: 0.1230 - lr: 0.0010
# Epoch 19/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4182 - mse: 0.1328 - val_loss: 0.4041 - val_mse: 0.1230 - lr: 0.0010
# Epoch 20/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4097 - mse: 0.1321 - val_loss: 0.3961 - val_mse: 0.1227 - lr: 0.0010
# Epoch 21/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4022 - mse: 0.1323 - val_loss: 0.3884 - val_mse: 0.1226 - lr: 0.0010
# Epoch 22/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3940 - mse: 0.1317 - val_loss: 0.3808 - val_mse: 0.1225 - lr: 0.0010
# Epoch 23/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.3848 - mse: 0.1300 - val_loss: 0.3733 - val_mse: 0.1225 - lr: 0.0010
# Epoch 24/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.3753 - mse: 0.1279 - val_loss: 0.3660 - val_mse: 0.1226 - lr: 0.0010
# Epoch 25/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3663 - mse: 0.1263 - val_loss: 0.3586 - val_mse: 0.1225 - lr: 0.0010
# Epoch 26/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3607 - mse: 0.1279 - val_loss: 0.3515 - val_mse: 0.1226 - lr: 0.0010
# Epoch 27/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3516 - mse: 0.1260 - val_loss: 0.3444 - val_mse: 0.1226 - lr: 0.0010
# Epoch 28/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3429 - mse: 0.1243 - val_loss: 0.3374 - val_mse: 0.1227 - lr: 0.0010
# Epoch 29/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3363 - mse: 0.1248 - val_loss: 0.3304 - val_mse: 0.1226 - lr: 0.0010
# Epoch 30/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.3283 - mse: 0.1237 - val_loss: 0.3235 - val_mse: 0.1225 - lr: 0.0010
# Epoch 31/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3182 - mse: 0.1203 - val_loss: 0.3167 - val_mse: 0.1225 - lr: 0.0010
# Epoch 32/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3123 - mse: 0.1211 - val_loss: 0.3101 - val_mse: 0.1225 - lr: 0.0010
# Epoch 33/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.3086 - mse: 0.1240 - val_loss: 0.3036 - val_mse: 0.1225 - lr: 0.0010
# Epoch 34/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3012 - mse: 0.1231 - val_loss: 0.2972 - val_mse: 0.1225 - lr: 0.0010
# Epoch 35/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2908 - mse: 0.1190 - val_loss: 0.2909 - val_mse: 0.1224 - lr: 0.0010
# Epoch 36/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2867 - mse: 0.1211 - val_loss: 0.2847 - val_mse: 0.1224 - lr: 0.0010
# Epoch 37/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2798 - mse: 0.1202 - val_loss: 0.2787 - val_mse: 0.1224 - lr: 0.0010
# Epoch 38/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2753 - mse: 0.1218 - val_loss: 0.2728 - val_mse: 0.1224 - lr: 0.0010
# Epoch 39/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2671 - mse: 0.1194 - val_loss: 0.2671 - val_mse: 0.1225 - lr: 0.0010
# Epoch 40/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2617 - mse: 0.1197 - val_loss: 0.2615 - val_mse: 0.1225 - lr: 0.0010
# Epoch 41/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2553 - mse: 0.1188 - val_loss: 0.2560 - val_mse: 0.1225 - lr: 0.0010
# Epoch 42/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2495 - mse: 0.1185 - val_loss: 0.2506 - val_mse: 0.1225 - lr: 0.0010
# Epoch 43/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2446 - mse: 0.1188 - val_loss: 0.2455 - val_mse: 0.1225 - lr: 0.0010
# Epoch 44/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2386 - mse: 0.1179 - val_loss: 0.2404 - val_mse: 0.1225 - lr: 0.0010
# Epoch 45/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2328 - mse: 0.1172 - val_loss: 0.2354 - val_mse: 0.1225 - lr: 0.0010
# Epoch 46/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2263 - mse: 0.1155 - val_loss: 0.2308 - val_mse: 0.1227 - lr: 0.0010
# Epoch 47/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2219 - mse: 0.1159 - val_loss: 0.2261 - val_mse: 0.1226 - lr: 0.0010
# Epoch 48/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2179 - mse: 0.1164 - val_loss: 0.2218 - val_mse: 0.1227 - lr: 0.0010
# Epoch 49/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2118 - mse: 0.1147 - val_loss: 0.2175 - val_mse: 0.1227 - lr: 0.0010
# Epoch 50/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.2085 - mse: 0.1156 - val_loss: 0.2134 - val_mse: 0.1228 - lr: 0.0010
# Epoch 51/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.2026 - mse: 0.1139 - val_loss: 0.2091 - val_mse: 0.1226 - lr: 0.0010
# Epoch 52/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1976 - mse: 0.1128 - val_loss: 0.2048 - val_mse: 0.1222 - lr: 0.0010
# Epoch 53/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1919 - mse: 0.1111 - val_loss: 0.2004 - val_mse: 0.1217 - lr: 0.0010
# Epoch 54/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1883 - mse: 0.1113 - val_loss: 0.1965 - val_mse: 0.1215 - lr: 0.0010
# Epoch 55/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1857 - mse: 0.1123 - val_loss: 0.1929 - val_mse: 0.1216 - lr: 0.0010
# Epoch 56/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1819 - mse: 0.1122 - val_loss: 0.1893 - val_mse: 0.1214 - lr: 0.0010
# Epoch 57/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1754 - mse: 0.1090 - val_loss: 0.1858 - val_mse: 0.1214 - lr: 0.0010
# Epoch 58/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1718 - mse: 0.1088 - val_loss: 0.1825 - val_mse: 0.1212 - lr: 0.0010
# Epoch 59/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1698 - mse: 0.1100 - val_loss: 0.1792 - val_mse: 0.1210 - lr: 0.0010
# Epoch 60/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.1639 - mse: 0.1071 - val_loss: 0.1762 - val_mse: 0.1210 - lr: 0.0010
# Epoch 61/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1626 - mse: 0.1086 - val_loss: 0.1736 - val_mse: 0.1212 - lr: 0.0010
# Epoch 62/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1575 - mse: 0.1064 - val_loss: 0.1708 - val_mse: 0.1212 - lr: 0.0010
# Epoch 63/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1580 - mse: 0.1096 - val_loss: 0.1682 - val_mse: 0.1213 - lr: 0.0010
# Epoch 64/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1532 - mse: 0.1073 - val_loss: 0.1656 - val_mse: 0.1211 - lr: 0.0010
# Epoch 65/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1508 - mse: 0.1074 - val_loss: 0.1630 - val_mse: 0.1210 - lr: 0.0010
# Epoch 66/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1486 - mse: 0.1077 - val_loss: 0.1608 - val_mse: 0.1212 - lr: 0.0010
# Epoch 67/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1481 - mse: 0.1095 - val_loss: 0.1584 - val_mse: 0.1210 - lr: 0.0010
# Epoch 68/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1403 - mse: 0.1040 - val_loss: 0.1561 - val_mse: 0.1210 - lr: 0.0010
# Epoch 69/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.1404 - mse: 0.1062 - val_loss: 0.1546 - val_mse: 0.1215 - lr: 0.0010
# Epoch 70/100
# 15/15 [==============================] - 0s 20ms/step - loss: 0.1379 - mse: 0.1056 - val_loss: 0.1531 - val_mse: 0.1218 - lr: 0.0010
# Epoch 71/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1376 - mse: 0.1071 - val_loss: 0.1513 - val_mse: 0.1217 - lr: 0.0010
# Epoch 72/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1344 - mse: 0.1055 - val_loss: 0.1498 - val_mse: 0.1218 - lr: 0.0010
# Epoch 73/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1337 - mse: 0.1065 - val_loss: 0.1483 - val_mse: 0.1219 - lr: 0.0010
# Epoch 74/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.1290 - mse: 0.1033 - val_loss: 0.1469 - val_mse: 0.1220 - lr: 0.0010
# Epoch 75/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1287 - mse: 0.1044 - val_loss: 0.1461 - val_mse: 0.1226 - lr: 0.0010
# Epoch 76/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1263 - mse: 0.1033 - val_loss: 0.1452 - val_mse: 0.1229 - lr: 0.0010
# Epoch 77/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1278 - mse: 0.1061 - val_loss: 0.1437 - val_mse: 0.1226 - lr: 0.0010
# Epoch 78/100
# 15/15 [==============================] - 0s 20ms/step - loss: 0.1242 - mse: 0.1035 - val_loss: 0.1429 - val_mse: 0.1229 - lr: 0.0010
# Epoch 79/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.1229 - mse: 0.1035 - val_loss: 0.1418 - val_mse: 0.1230 - lr: 0.0010
# Epoch 80/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1232 - mse: 0.1048 - val_loss: 0.1404 - val_mse: 0.1226 - lr: 0.0010
# Epoch 81/100
# 15/15 [==============================] - 0s 20ms/step - loss: 0.1215 - mse: 0.1041 - val_loss: 0.1394 - val_mse: 0.1224 - lr: 0.0010
# Epoch 82/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.1213 - mse: 0.1048 - val_loss: 0.1391 - val_mse: 0.1230 - lr: 0.0010
# Epoch 83/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1198 - mse: 0.1042 - val_loss: 0.1386 - val_mse: 0.1233 - lr: 0.0010
# Epoch 84/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1180 - mse: 0.1031 - val_loss: 0.1377 - val_mse: 0.1232 - lr: 0.0010
# Epoch 85/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1178 - mse: 0.1036 - val_loss: 0.1365 - val_mse: 0.1226 - lr: 0.0010
# Epoch 86/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1158 - mse: 0.1022 - val_loss: 0.1366 - val_mse: 0.1233 - lr: 0.0010
# Epoch 87/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1161 - mse: 0.1031 - val_loss: 0.1368 - val_mse: 0.1240 - lr: 0.0010
# Epoch 88/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.1147 - mse: 0.1022 - val_loss: 0.1362 - val_mse: 0.1240 - lr: 0.0010
# Epoch 89/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1143 - mse: 0.1023 - val_loss: 0.1362 - val_mse: 0.1245 - lr: 0.0010
# Epoch 90/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1140 - mse: 0.1024 - val_loss: 0.1350 - val_mse: 0.1236 - lr: 0.0010
# Epoch 91/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1121 - mse: 0.1009 - val_loss: 0.1359 - val_mse: 0.1249 - lr: 0.0010
# Epoch 92/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1133 - mse: 0.1024 - val_loss: 0.1363 - val_mse: 0.1255 - lr: 0.0010
# Epoch 93/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1133 - mse: 0.1026 - val_loss: 0.1360 - val_mse: 0.1254 - lr: 0.0010
# Epoch 94/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1116 - mse: 0.1012 - val_loss: 0.1359 - val_mse: 0.1255 - lr: 2.0000e-04
# Epoch 95/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1105 - mse: 0.1002 - val_loss: 0.1357 - val_mse: 0.1256 - lr: 2.0000e-04
# Epoch 1/100
# 15/15 [==============================] - 2s 29ms/step - loss: 0.6467 - mse: 0.2095 - val_loss: 0.5530 - val_mse: 0.1204 - lr: 0.0010
# Epoch 2/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.6286 - mse: 0.2000 - val_loss: 0.5450 - val_mse: 0.1210 - lr: 0.0010
# Epoch 3/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.6062 - mse: 0.1861 - val_loss: 0.5368 - val_mse: 0.1213 - lr: 0.0010
# Epoch 4/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5969 - mse: 0.1852 - val_loss: 0.5289 - val_mse: 0.1217 - lr: 0.0010
# Epoch 5/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5744 - mse: 0.1710 - val_loss: 0.5220 - val_mse: 0.1231 - lr: 0.0010
# Epoch 6/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5688 - mse: 0.1737 - val_loss: 0.5140 - val_mse: 0.1233 - lr: 0.0010
# Epoch 7/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.5537 - mse: 0.1667 - val_loss: 0.5056 - val_mse: 0.1231 - lr: 0.0010
# Epoch 8/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5403 - mse: 0.1615 - val_loss: 0.4972 - val_mse: 0.1227 - lr: 0.0010
# Epoch 9/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5363 - mse: 0.1655 - val_loss: 0.4897 - val_mse: 0.1232 - lr: 0.0010
# Epoch 10/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5237 - mse: 0.1607 - val_loss: 0.4816 - val_mse: 0.1229 - lr: 0.0010
# Epoch 11/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5053 - mse: 0.1501 - val_loss: 0.4728 - val_mse: 0.1218 - lr: 0.0010
# Epoch 12/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.4995 - mse: 0.1521 - val_loss: 0.4647 - val_mse: 0.1215 - lr: 0.0010
# Epoch 13/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4845 - mse: 0.1448 - val_loss: 0.4562 - val_mse: 0.1207 - lr: 0.0010
# Epoch 14/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4816 - mse: 0.1496 - val_loss: 0.4482 - val_mse: 0.1203 - lr: 0.0010
# Epoch 15/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4665 - mse: 0.1421 - val_loss: 0.4405 - val_mse: 0.1202 - lr: 0.0010
# Epoch 16/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4581 - mse: 0.1412 - val_loss: 0.4329 - val_mse: 0.1201 - lr: 0.0010
# Epoch 17/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4497 - mse: 0.1403 - val_loss: 0.4255 - val_mse: 0.1202 - lr: 0.0010
# Epoch 18/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4387 - mse: 0.1368 - val_loss: 0.4183 - val_mse: 0.1203 - lr: 0.0010
# Epoch 19/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4303 - mse: 0.1358 - val_loss: 0.4109 - val_mse: 0.1204 - lr: 0.0010
# Epoch 20/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4204 - mse: 0.1333 - val_loss: 0.4035 - val_mse: 0.1204 - lr: 0.0010
# Epoch 21/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4123 - mse: 0.1326 - val_loss: 0.3959 - val_mse: 0.1202 - lr: 0.0010
# Epoch 22/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4050 - mse: 0.1326 - val_loss: 0.3886 - val_mse: 0.1200 - lr: 0.0010
# Epoch 23/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.3953 - mse: 0.1300 - val_loss: 0.3814 - val_mse: 0.1200 - lr: 0.0010
# Epoch 24/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3870 - mse: 0.1288 - val_loss: 0.3744 - val_mse: 0.1200 - lr: 0.0010
# Epoch 25/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3801 - mse: 0.1289 - val_loss: 0.3674 - val_mse: 0.1200 - lr: 0.0010
# Epoch 26/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3728 - mse: 0.1286 - val_loss: 0.3605 - val_mse: 0.1200 - lr: 0.0010
# Epoch 27/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3630 - mse: 0.1257 - val_loss: 0.3537 - val_mse: 0.1201 - lr: 0.0010
# Epoch 28/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3563 - mse: 0.1258 - val_loss: 0.3469 - val_mse: 0.1201 - lr: 0.0010
# Epoch 29/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.3472 - mse: 0.1235 - val_loss: 0.3402 - val_mse: 0.1201 - lr: 0.0010
# Epoch 30/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3402 - mse: 0.1232 - val_loss: 0.3335 - val_mse: 0.1201 - lr: 0.0010
# Epoch 31/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.3327 - mse: 0.1223 - val_loss: 0.3271 - val_mse: 0.1202 - lr: 0.0010
# Epoch 32/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3225 - mse: 0.1186 - val_loss: 0.3207 - val_mse: 0.1202 - lr: 0.0010
# Epoch 33/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.3184 - mse: 0.1209 - val_loss: 0.3144 - val_mse: 0.1202 - lr: 0.0010
# Epoch 34/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3146 - mse: 0.1234 - val_loss: 0.3082 - val_mse: 0.1203 - lr: 0.0010
# Epoch 35/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3064 - mse: 0.1214 - val_loss: 0.3021 - val_mse: 0.1204 - lr: 0.0010
# Epoch 36/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2999 - mse: 0.1209 - val_loss: 0.2960 - val_mse: 0.1203 - lr: 0.0010
# Epoch 37/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.2909 - mse: 0.1179 - val_loss: 0.2901 - val_mse: 0.1203 - lr: 0.0010
# Epoch 38/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.2854 - mse: 0.1182 - val_loss: 0.2842 - val_mse: 0.1202 - lr: 0.0010
# Epoch 39/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.2791 - mse: 0.1178 - val_loss: 0.2785 - val_mse: 0.1202 - lr: 0.0010
# Epoch 40/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.2726 - mse: 0.1169 - val_loss: 0.2729 - val_mse: 0.1202 - lr: 0.0010
# Epoch 41/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.2653 - mse: 0.1151 - val_loss: 0.2675 - val_mse: 0.1202 - lr: 0.0010
# Epoch 42/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.2596 - mse: 0.1148 - val_loss: 0.2621 - val_mse: 0.1202 - lr: 0.0010
# Epoch 43/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.2558 - mse: 0.1163 - val_loss: 0.2570 - val_mse: 0.1203 - lr: 0.0010
# Epoch 44/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2495 - mse: 0.1152 - val_loss: 0.2519 - val_mse: 0.1204 - lr: 0.0010
# Epoch 45/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.2441 - mse: 0.1149 - val_loss: 0.2470 - val_mse: 0.1205 - lr: 0.0010
# Epoch 46/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2368 - mse: 0.1125 - val_loss: 0.2423 - val_mse: 0.1207 - lr: 0.0010
# Epoch 47/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2329 - mse: 0.1135 - val_loss: 0.2378 - val_mse: 0.1209 - lr: 0.0010
# Epoch 48/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2276 - mse: 0.1129 - val_loss: 0.2333 - val_mse: 0.1211 - lr: 0.0010
# Epoch 49/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2226 - mse: 0.1125 - val_loss: 0.2288 - val_mse: 0.1211 - lr: 0.0010
# Epoch 50/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2162 - mse: 0.1106 - val_loss: 0.2246 - val_mse: 0.1213 - lr: 0.0010
# Epoch 51/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2110 - mse: 0.1098 - val_loss: 0.2204 - val_mse: 0.1215 - lr: 0.0010
# Epoch 52/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2044 - mse: 0.1074 - val_loss: 0.2168 - val_mse: 0.1222 - lr: 0.0010
# Epoch 53/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.2008 - mse: 0.1080 - val_loss: 0.2130 - val_mse: 0.1224 - lr: 0.0010
# Epoch 54/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1960 - mse: 0.1072 - val_loss: 0.2095 - val_mse: 0.1228 - lr: 0.0010
# Epoch 55/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1948 - mse: 0.1099 - val_loss: 0.2057 - val_mse: 0.1228 - lr: 0.0010
# Epoch 56/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1894 - mse: 0.1083 - val_loss: 0.2022 - val_mse: 0.1231 - lr: 0.0010
# Epoch 57/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1853 - mse: 0.1078 - val_loss: 0.1987 - val_mse: 0.1232 - lr: 0.0010
# Epoch 58/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1789 - mse: 0.1051 - val_loss: 0.1959 - val_mse: 0.1239 - lr: 0.0010
# Epoch 59/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1745 - mse: 0.1041 - val_loss: 0.1931 - val_mse: 0.1246 - lr: 0.0010
# Epoch 60/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1726 - mse: 0.1056 - val_loss: 0.1895 - val_mse: 0.1242 - lr: 0.0010
# Epoch 61/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1697 - mse: 0.1059 - val_loss: 0.1864 - val_mse: 0.1243 - lr: 0.0010
# Epoch 62/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1648 - mse: 0.1042 - val_loss: 0.1833 - val_mse: 0.1244 - lr: 0.0010
# Epoch 63/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1623 - mse: 0.1047 - val_loss: 0.1805 - val_mse: 0.1245 - lr: 0.0010
# Epoch 64/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1584 - mse: 0.1037 - val_loss: 0.1777 - val_mse: 0.1246 - lr: 0.0010
# Epoch 65/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1565 - mse: 0.1047 - val_loss: 0.1757 - val_mse: 0.1253 - lr: 0.0010
# Epoch 66/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.1540 - mse: 0.1048 - val_loss: 0.1732 - val_mse: 0.1255 - lr: 0.0010
# Epoch 67/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1512 - mse: 0.1046 - val_loss: 0.1708 - val_mse: 0.1255 - lr: 0.0010
# Epoch 68/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1467 - mse: 0.1025 - val_loss: 0.1690 - val_mse: 0.1262 - lr: 0.0010
# Epoch 69/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1453 - mse: 0.1035 - val_loss: 0.1661 - val_mse: 0.1256 - lr: 0.0010
# Epoch 70/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1449 - mse: 0.1053 - val_loss: 0.1634 - val_mse: 0.1251 - lr: 0.0010
# Epoch 71/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1401 - mse: 0.1028 - val_loss: 0.1614 - val_mse: 0.1251 - lr: 0.0010
# Epoch 72/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1369 - mse: 0.1017 - val_loss: 0.1604 - val_mse: 0.1262 - lr: 0.0010
# Epoch 73/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1359 - mse: 0.1025 - val_loss: 0.1576 - val_mse: 0.1253 - lr: 0.0010
# Epoch 74/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1338 - mse: 0.1022 - val_loss: 0.1557 - val_mse: 0.1251 - lr: 0.0010
# Epoch 75/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1308 - mse: 0.1009 - val_loss: 0.1547 - val_mse: 0.1257 - lr: 0.0010
# Epoch 76/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1292 - mse: 0.1009 - val_loss: 0.1537 - val_mse: 0.1261 - lr: 0.0010
# Epoch 77/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1293 - mse: 0.1023 - val_loss: 0.1534 - val_mse: 0.1272 - lr: 0.0010
# Epoch 78/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1273 - mse: 0.1018 - val_loss: 0.1518 - val_mse: 0.1270 - lr: 0.0010
# Epoch 79/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1282 - mse: 0.1041 - val_loss: 0.1493 - val_mse: 0.1259 - lr: 0.0010
# Epoch 80/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1235 - mse: 0.1007 - val_loss: 0.1475 - val_mse: 0.1255 - lr: 0.0010
# Epoch 81/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1220 - mse: 0.1005 - val_loss: 0.1477 - val_mse: 0.1269 - lr: 0.0010
# Epoch 82/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1214 - mse: 0.1011 - val_loss: 0.1465 - val_mse: 0.1267 - lr: 0.0010
# Epoch 83/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1203 - mse: 0.1009 - val_loss: 0.1455 - val_mse: 0.1266 - lr: 0.0010
# Epoch 84/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1183 - mse: 0.0999 - val_loss: 0.1443 - val_mse: 0.1263 - lr: 0.0010
# Epoch 85/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1161 - mse: 0.0986 - val_loss: 0.1448 - val_mse: 0.1277 - lr: 0.0010
# Epoch 86/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1154 - mse: 0.0986 - val_loss: 0.1439 - val_mse: 0.1275 - lr: 0.0010
# Epoch 87/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1144 - mse: 0.0982 - val_loss: 0.1439 - val_mse: 0.1282 - lr: 0.0010
# Epoch 88/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1159 - mse: 0.1004 - val_loss: 0.1421 - val_mse: 0.1269 - lr: 0.0010
# Epoch 89/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1150 - mse: 0.1002 - val_loss: 0.1431 - val_mse: 0.1286 - lr: 0.0010
# Epoch 90/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1151 - mse: 0.1008 - val_loss: 0.1429 - val_mse: 0.1289 - lr: 0.0010
# Epoch 91/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.1147 - mse: 0.1010 - val_loss: 0.1417 - val_mse: 0.1283 - lr: 0.0010
# Epoch 92/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1110 - mse: 0.0978 - val_loss: 0.1417 - val_mse: 0.1288 - lr: 0.0010
# Epoch 93/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1132 - mse: 0.1005 - val_loss: 0.1425 - val_mse: 0.1300 - lr: 0.0010
# Epoch 94/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1121 - mse: 0.0996 - val_loss: 0.1441 - val_mse: 0.1318 - lr: 0.0010
# Epoch 95/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1115 - mse: 0.0993 - val_loss: 0.1443 - val_mse: 0.1322 - lr: 2.0000e-04
# Epoch 96/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1112 - mse: 0.0992 - val_loss: 0.1443 - val_mse: 0.1324 - lr: 2.0000e-04
# Epoch 97/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1110 - mse: 0.0993 - val_loss: 0.1444 - val_mse: 0.1328 - lr: 2.0000e-04
# Epoch 1/100
# 15/15 [==============================] - 4s 42ms/step - loss: 0.6476 - mse: 0.2091 - val_loss: 0.5539 - val_mse: 0.1201 - lr: 0.0010
# Epoch 2/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.6291 - mse: 0.1992 - val_loss: 0.5454 - val_mse: 0.1202 - lr: 0.0010
# Epoch 3/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.6142 - mse: 0.1930 - val_loss: 0.5369 - val_mse: 0.1203 - lr: 0.0010
# Epoch 4/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.6025 - mse: 0.1898 - val_loss: 0.5282 - val_mse: 0.1201 - lr: 0.0010
# Epoch 5/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5788 - mse: 0.1745 - val_loss: 0.5198 - val_mse: 0.1200 - lr: 0.0010
# Epoch 6/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.5709 - mse: 0.1748 - val_loss: 0.5118 - val_mse: 0.1202 - lr: 0.0010
# Epoch 7/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.5574 - mse: 0.1694 - val_loss: 0.5038 - val_mse: 0.1202 - lr: 0.0010
# Epoch 8/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.5446 - mse: 0.1647 - val_loss: 0.4961 - val_mse: 0.1205 - lr: 0.0010
# Epoch 9/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.5355 - mse: 0.1636 - val_loss: 0.4888 - val_mse: 0.1212 - lr: 0.0010
# Epoch 10/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.5255 - mse: 0.1614 - val_loss: 0.4817 - val_mse: 0.1219 - lr: 0.0010
# Epoch 11/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.5154 - mse: 0.1592 - val_loss: 0.4743 - val_mse: 0.1223 - lr: 0.0010
# Epoch 12/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.5043 - mse: 0.1557 - val_loss: 0.4663 - val_mse: 0.1219 - lr: 0.0010
# Epoch 13/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4945 - mse: 0.1535 - val_loss: 0.4588 - val_mse: 0.1219 - lr: 0.0010
# Epoch 14/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4808 - mse: 0.1473 - val_loss: 0.4500 - val_mse: 0.1206 - lr: 0.0010
# Epoch 15/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4738 - mse: 0.1478 - val_loss: 0.4421 - val_mse: 0.1202 - lr: 0.0010
# Epoch 16/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4606 - mse: 0.1420 - val_loss: 0.4346 - val_mse: 0.1200 - lr: 0.0010
# Epoch 17/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4551 - mse: 0.1438 - val_loss: 0.4272 - val_mse: 0.1199 - lr: 0.0010
# Epoch 18/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4456 - mse: 0.1416 - val_loss: 0.4201 - val_mse: 0.1200 - lr: 0.0010
# Epoch 19/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4392 - mse: 0.1424 - val_loss: 0.4130 - val_mse: 0.1200 - lr: 0.0010
# Epoch 20/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.4258 - mse: 0.1361 - val_loss: 0.4058 - val_mse: 0.1199 - lr: 0.0010
# Epoch 21/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4167 - mse: 0.1341 - val_loss: 0.3988 - val_mse: 0.1200 - lr: 0.0010
# Epoch 22/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4098 - mse: 0.1342 - val_loss: 0.3918 - val_mse: 0.1200 - lr: 0.0010
# Epoch 23/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4028 - mse: 0.1341 - val_loss: 0.3848 - val_mse: 0.1199 - lr: 0.0010
# Epoch 24/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3889 - mse: 0.1272 - val_loss: 0.3779 - val_mse: 0.1199 - lr: 0.0010
# Epoch 25/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3825 - mse: 0.1277 - val_loss: 0.3712 - val_mse: 0.1201 - lr: 0.0010
# Epoch 26/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.3791 - mse: 0.1311 - val_loss: 0.3646 - val_mse: 0.1202 - lr: 0.0010
# Epoch 27/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3721 - mse: 0.1308 - val_loss: 0.3577 - val_mse: 0.1201 - lr: 0.0010
# Epoch 28/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3656 - mse: 0.1310 - val_loss: 0.3510 - val_mse: 0.1200 - lr: 0.0010
# Epoch 29/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3549 - mse: 0.1269 - val_loss: 0.3445 - val_mse: 0.1200 - lr: 0.0010
# Epoch 30/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3467 - mse: 0.1252 - val_loss: 0.3381 - val_mse: 0.1201 - lr: 0.0010
# Epoch 31/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3383 - mse: 0.1232 - val_loss: 0.3316 - val_mse: 0.1200 - lr: 0.0010
# Epoch 32/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3321 - mse: 0.1234 - val_loss: 0.3253 - val_mse: 0.1200 - lr: 0.0010
# Epoch 33/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3275 - mse: 0.1251 - val_loss: 0.3190 - val_mse: 0.1200 - lr: 0.0010
# Epoch 34/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.3167 - mse: 0.1205 - val_loss: 0.3128 - val_mse: 0.1198 - lr: 0.0010
# Epoch 35/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3118 - mse: 0.1217 - val_loss: 0.3067 - val_mse: 0.1198 - lr: 0.0010
# Epoch 36/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3055 - mse: 0.1214 - val_loss: 0.3007 - val_mse: 0.1198 - lr: 0.0010
# Epoch 37/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.3005 - mse: 0.1223 - val_loss: 0.2948 - val_mse: 0.1198 - lr: 0.0010
# Epoch 38/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2900 - mse: 0.1177 - val_loss: 0.2892 - val_mse: 0.1200 - lr: 0.0010
# Epoch 39/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.2865 - mse: 0.1200 - val_loss: 0.2837 - val_mse: 0.1201 - lr: 0.0010
# Epoch 40/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2812 - mse: 0.1203 - val_loss: 0.2780 - val_mse: 0.1201 - lr: 0.0010
# Epoch 41/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2735 - mse: 0.1181 - val_loss: 0.2724 - val_mse: 0.1199 - lr: 0.0010
# Epoch 42/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2665 - mse: 0.1165 - val_loss: 0.2671 - val_mse: 0.1199 - lr: 0.0010
# Epoch 43/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2637 - mse: 0.1190 - val_loss: 0.2616 - val_mse: 0.1197 - lr: 0.0010
# Epoch 44/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2544 - mse: 0.1149 - val_loss: 0.2564 - val_mse: 0.1197 - lr: 0.0010
# Epoch 45/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2499 - mse: 0.1155 - val_loss: 0.2514 - val_mse: 0.1198 - lr: 0.0010
# Epoch 46/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2451 - mse: 0.1157 - val_loss: 0.2464 - val_mse: 0.1197 - lr: 0.0010
# Epoch 47/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2378 - mse: 0.1134 - val_loss: 0.2412 - val_mse: 0.1194 - lr: 0.0010
# Epoch 48/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.2347 - mse: 0.1151 - val_loss: 0.2363 - val_mse: 0.1192 - lr: 0.0010
# Epoch 49/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2281 - mse: 0.1132 - val_loss: 0.2317 - val_mse: 0.1192 - lr: 0.0010
# Epoch 50/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2238 - mse: 0.1134 - val_loss: 0.2269 - val_mse: 0.1189 - lr: 0.0010
# Epoch 51/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2187 - mse: 0.1128 - val_loss: 0.2225 - val_mse: 0.1190 - lr: 0.0010
# Epoch 52/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2145 - mse: 0.1130 - val_loss: 0.2182 - val_mse: 0.1190 - lr: 0.0010
# Epoch 53/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2103 - mse: 0.1130 - val_loss: 0.2143 - val_mse: 0.1193 - lr: 0.0010
# Epoch 54/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.2045 - mse: 0.1113 - val_loss: 0.2102 - val_mse: 0.1193 - lr: 0.0010
# Epoch 55/100
# 15/15 [==============================] - 0s 20ms/step - loss: 0.1996 - mse: 0.1106 - val_loss: 0.2061 - val_mse: 0.1192 - lr: 0.0010
# Epoch 56/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.1950 - mse: 0.1099 - val_loss: 0.2023 - val_mse: 0.1193 - lr: 0.0010
# Epoch 57/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1904 - mse: 0.1092 - val_loss: 0.1986 - val_mse: 0.1195 - lr: 0.0010
# Epoch 58/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.1870 - mse: 0.1096 - val_loss: 0.1951 - val_mse: 0.1196 - lr: 0.0010
# Epoch 59/100
# 15/15 [==============================] - 0s 21ms/step - loss: 0.1831 - mse: 0.1092 - val_loss: 0.1915 - val_mse: 0.1196 - lr: 0.0010
# Epoch 60/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1789 - mse: 0.1085 - val_loss: 0.1883 - val_mse: 0.1198 - lr: 0.0010
# Epoch 61/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1755 - mse: 0.1085 - val_loss: 0.1851 - val_mse: 0.1198 - lr: 0.0010
# Epoch 62/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.1699 - mse: 0.1061 - val_loss: 0.1821 - val_mse: 0.1201 - lr: 0.0010
# Epoch 63/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1688 - mse: 0.1082 - val_loss: 0.1787 - val_mse: 0.1197 - lr: 0.0010
# Epoch 64/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.1651 - mse: 0.1074 - val_loss: 0.1759 - val_mse: 0.1197 - lr: 0.0010
# Epoch 65/100
# 15/15 [==============================] - 0s 19ms/step - loss: 0.1583 - mse: 0.1034 - val_loss: 0.1735 - val_mse: 0.1201 - lr: 0.0010
# Epoch 66/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.1578 - mse: 0.1057 - val_loss: 0.1712 - val_mse: 0.1205 - lr: 0.0010
# Epoch 67/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1563 - mse: 0.1069 - val_loss: 0.1684 - val_mse: 0.1203 - lr: 0.0010
# Epoch 68/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1514 - mse: 0.1045 - val_loss: 0.1658 - val_mse: 0.1202 - lr: 0.0010
# Epoch 69/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1532 - mse: 0.1087 - val_loss: 0.1633 - val_mse: 0.1201 - lr: 0.0010
# Epoch 70/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1464 - mse: 0.1043 - val_loss: 0.1612 - val_mse: 0.1203 - lr: 0.0010
# Epoch 71/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1456 - mse: 0.1057 - val_loss: 0.1592 - val_mse: 0.1206 - lr: 0.0010
# Epoch 72/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1442 - mse: 0.1065 - val_loss: 0.1572 - val_mse: 0.1207 - lr: 0.0010
# Epoch 73/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1395 - mse: 0.1038 - val_loss: 0.1560 - val_mse: 0.1214 - lr: 0.0010
# Epoch 74/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1378 - mse: 0.1042 - val_loss: 0.1545 - val_mse: 0.1219 - lr: 0.0010
# Epoch 75/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1362 - mse: 0.1044 - val_loss: 0.1532 - val_mse: 0.1224 - lr: 0.0010
# Epoch 76/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1353 - mse: 0.1053 - val_loss: 0.1514 - val_mse: 0.1224 - lr: 0.0010
# Epoch 77/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1320 - mse: 0.1038 - val_loss: 0.1496 - val_mse: 0.1223 - lr: 0.0010
# Epoch 78/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1296 - mse: 0.1030 - val_loss: 0.1480 - val_mse: 0.1222 - lr: 0.0010
# Epoch 79/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1284 - mse: 0.1033 - val_loss: 0.1460 - val_mse: 0.1216 - lr: 0.0010
# Epoch 80/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1282 - mse: 0.1044 - val_loss: 0.1444 - val_mse: 0.1212 - lr: 0.0010
# Epoch 81/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1272 - mse: 0.1046 - val_loss: 0.1431 - val_mse: 0.1212 - lr: 0.0010
# Epoch 82/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1257 - mse: 0.1042 - val_loss: 0.1423 - val_mse: 0.1214 - lr: 0.0010
# Epoch 83/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1249 - mse: 0.1045 - val_loss: 0.1420 - val_mse: 0.1222 - lr: 0.0010
# Epoch 84/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1235 - mse: 0.1043 - val_loss: 0.1408 - val_mse: 0.1222 - lr: 0.0010
# Epoch 85/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.1209 - mse: 0.1027 - val_loss: 0.1401 - val_mse: 0.1224 - lr: 0.0010
# Epoch 86/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1200 - mse: 0.1027 - val_loss: 0.1397 - val_mse: 0.1228 - lr: 0.0010
# Epoch 87/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1200 - mse: 0.1034 - val_loss: 0.1396 - val_mse: 0.1235 - lr: 0.0010
# Epoch 88/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1183 - mse: 0.1026 - val_loss: 0.1377 - val_mse: 0.1224 - lr: 0.0010
# Epoch 89/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1186 - mse: 0.1036 - val_loss: 0.1378 - val_mse: 0.1232 - lr: 0.0010
# Epoch 90/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1153 - mse: 0.1009 - val_loss: 0.1364 - val_mse: 0.1224 - lr: 0.0010
# Epoch 91/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1158 - mse: 0.1020 - val_loss: 0.1376 - val_mse: 0.1240 - lr: 0.0010
# Epoch 92/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1169 - mse: 0.1035 - val_loss: 0.1365 - val_mse: 0.1233 - lr: 0.0010
# Epoch 93/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1163 - mse: 0.1032 - val_loss: 0.1361 - val_mse: 0.1233 - lr: 0.0010
# Epoch 94/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1143 - mse: 0.1017 - val_loss: 0.1371 - val_mse: 0.1249 - lr: 0.0010
# Epoch 95/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.1127 - mse: 0.1007 - val_loss: 0.1364 - val_mse: 0.1247 - lr: 0.0010
# Epoch 96/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1129 - mse: 0.1014 - val_loss: 0.1347 - val_mse: 0.1235 - lr: 0.0010
# Epoch 97/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.1134 - mse: 0.1024 - val_loss: 0.1346 - val_mse: 0.1237 - lr: 0.0010
# Epoch 98/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.1126 - mse: 0.1018 - val_loss: 0.1335 - val_mse: 0.1230 - lr: 0.0010
# Epoch 99/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1117 - mse: 0.1012 - val_loss: 0.1363 - val_mse: 0.1259 - lr: 0.0010
# Epoch 100/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1113 - mse: 0.1010 - val_loss: 0.1361 - val_mse: 0.1259 - lr: 0.0010

# %% [markdown]
# #### Inisialisasi dan Pelatihan Model:

# %% [markdown]
# #### Visualisasi Hasil Pelatihan

# %%
# Visualisasi hasil training dan validasi
plt.plot(history.history['loss'], label='train_loss (MSE)')
plt.plot(history.history['val_loss'], label='val_loss (MSE)')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.show()

plt.plot(history.history['mse'], label='train_mse')
plt.plot(history.history['val_mse'], label='val_mse')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.legend()
plt.show()

# %% [markdown]
# ## hasil rekomendasi untuk user

# %%
# Buat DataFrame baru yang berisi semua pasangan pengguna-tempat yang mungkin
all_users = np.array(list(user_to_user_encoded.values()))
all_places = np.array(list(place_to_place_encoded.values()))
all_user_place = np.array(np.meshgrid(all_users, all_places)).T.reshape(-1, 2)
df_all_user_place = pd.DataFrame(all_user_place, columns=['user', 'place'])

# Gunakan model yang sudah dilatih untuk membuat prediksi rating
predictions = model.predict([df_all_user_place['user'], df_all_user_place['place']])

# Tambahkan prediksi rating ke DataFrame
df_all_user_place['predicted_rating'] = predictions.flatten()

# Urutkan hasil prediksi berdasarkan rating tertinggi
df_recommendations = df_all_user_place.sort_values(by='predicted_rating', ascending=False)

# Tampilkan hasil rekomendasi dalam bentuk DataFrame
print(df_recommendations.head(10))
# Out:
# 975/975 [==============================] - 2s 2ms/step
#        user  place  predicted_rating
# 24220   232     92          0.778493
# 18916   181     92          0.774382
# 20164   193     92          0.774003
# 14860   142     92          0.767202
# 24153   232     25          0.765203
# 24182   232     54          0.764195
# 1756     16     92          0.762178
# 23388   224     92          0.761433
# 18849   181     25          0.760974
# 24218   232     90          0.760693

# %%
# Group the recommendations by place and sort them by predicted rating in descending order
grouped_recommendations = df_recommendations.groupby('place').apply(lambda x: x.sort_values(by='predicted_rating', ascending=False))

# Print the top 10 recommendations with the highest rating, considering only one recommendation per place
print("Top 10 Cultural Recommendations:")
seen_places = set()
recommendations_count = 0
for index, row in grouped_recommendations.iterrows():
    place_id = place_encoded_to_place[row['place']]
    if place_id not in seen_places:
        place_details = place[place['Place_Id'] == place_id]
        category = place_details['Category'].iloc[0]

        # Check if the place belongs to the 'Culture' category
        if category == 'Taman Hiburan':
            place_name = place_details['Place_Name'].iloc[0]
            price = place_details['Price'].iloc[0]
            rating = place_details['Rating'].iloc[0]

            print(f"Place ID: {place_id}")
            print(f"Place Name: {place_name}")
            print(f"Category: {category}")
            print(f"Price: {price}")
            print(f"Rating: {rating}")
            print("\n")

            seen_places.add(place_id)
            recommendations_count += 1

            if recommendations_count >= 10:
                break
# Out:
# Top 10 Cultural Recommendations:
# Place ID: 3
# Place Name: Dunia Fantasi
# Category: Taman Hiburan
# Price: 270000
# Rating: 4.6
#
#
# Place ID: 4
# Place Name: Taman Mini Indonesia Indah (TMII)
# Category: Taman Hiburan
# Price: 10000
# Rating: 4.5
#
#
# Place ID: 5
# Place Name: Atlantis Water Adventure
# Category: Taman Hiburan
# Price: 94000
# Rating: 4.5
#
#
# Place ID: 6
# Place Name: Taman Impian Jaya Ancol
# Category: Taman Hiburan
# Price: 25000
# Rating: 4.5
#
#
# Place ID: 8
# Place Name: Ocean Ecopark
# Category: Taman Hiburan
# Price: 180000
# Rating: 4.0
#
#
# Place ID: 19
# Place Name: Kidzania
# Category: Taman Hiburan
# Price: 185000
# Rating: 4.6
#
#
# Place ID: 85
# Place Name: Taman Pintar Yogyakarta
# Category: Taman Hiburan
# Price: 6000
# Rating: 4.5
#
#
# Place ID: 87
# Place Name: Sindu Kusuma Edupark (SKE)
# Category: Taman Hiburan
# Price: 20000
# Rating: 4.2
#
#
# Place ID: 90
# Place Name: Kampung Wisata Taman Sari
# Category: Taman Hiburan
# Price: 5000
# Rating: 4.6
#
#
# Place ID: 91
# Place Name: Situs Warungboto
# Category: Taman Hiburan
# Price: 0
# Rating: 4.4

# %%
import pandas as pd
import numpy as np

# Membaca data baru
new_user = pd.read_csv('new_user_data.csv')
new_rating = pd.read_csv('sample_ratings.csv')

# Menampilkan beberapa baris pertama dari data baru untuk memastikan terbaca dengan benar
print(new_user.head())
print(new_rating.head())

# Menamakan ulang kolom untuk konsistensi jika diperlukan
new_rating.rename(columns={'place_id': 'Place_Id', 'user_id': 'User_Id', 'rating': 'Place_Ratings'}, inplace=True)

# Menggabungkan data rating baru dengan data tempat untuk mendapatkan informasi lengkap tempat
new_rating_merged = pd.merge(new_rating, place, on='Place_Id', how='left')

# Menampilkan beberapa baris pertama dari data yang digabungkan untuk memastikan penggabungan benar
print(new_rating_merged.head())

# Menggabungkan data baru dengan user data sebelumnya
new_user_encoded = new_user.copy()
new_user_encoded['user'] = new_user_encoded['User_Id'].map(user_to_user_encoded)

# Lakukan encoding pada User_Id dan Place_Id untuk data rating baru
new_rating_merged['user'] = new_rating_merged['User_Id'].map(user_to_user_encoded)
new_rating_merged['place'] = new_rating_merged['Place_Id'].map(place_to_place_encoded)

# Menghapus baris dengan nilai NaN akibat Place_Id atau User_Id yang tidak ada dalam dictionary
new_rating_merged = new_rating_merged.dropna(subset=['user', 'place'])

# Melakukan prediksi dengan model
predictions = model.predict([new_rating_merged['user'], new_rating_merged['place']])

# Menambahkan hasil prediksi ke DataFrame
new_rating_merged['predicted_rating'] = predictions.flatten()

# Menampilkan hasil prediksi
print(new_rating_merged[['User_Id', 'Place_Id', 'Place_Name', 'Category', 'predicted_rating']])
# Out:
#    User_Id                     Location  Age
# 0        1  Yogyakarta, D.I. Yogyakarta   54
# 1        2           Malang, Jawa Timur   42
# 2        3              Cilegon, Banten   29
# 3        4           Bekasi, Jawa Barat   15
# 4        5           Bekasi, Jawa Barat   44
#    place_id  user_id  rating
# 0         1      101     4.5
# 1         2      102     3.8
# 2         3      103     4.2
# 3         4      104     5.0
# 4         5      105     4.7
#    Place_Id  User_Id  Place_Ratings                         Place_Name  \
# 0         1      101            4.5                   Monumen Nasional
# 1         2      102            3.8                           Kota Tua
# 2         3      103            4.2                      Dunia Fantasi
# 3         4      104            5.0  Taman Mini Indonesia Indah (TMII)
# 4         5      105            4.7           Atlantis Water Adventure
#
#                                          Description       Category     City  \
# 0  Monumen Nasional atau yang populer disingkat d...         Budaya  Jakarta
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...         Budaya  Jakarta
# 2  Dunia Fantasi atau disebut juga Dufan adalah t...  Taman Hiburan  Jakarta
# 3  Taman Mini Indonesia Indah merupakan suatu kaw...  Taman Hiburan  Jakarta
# 4  Atlantis Water Adventure atau dikenal dengan A...  Taman Hiburan  Jakarta
#
#     Price  Rating                                       Coordinate       Lat  \
# 0   20000     4.6          {'lat': -6.1753924, 'lng': 106.8271528} -6.175392
# 1       0     4.6  {'lat': -6.137644799999999, 'lng': 106.8171245} -6.137645
# 2  270000     4.6  {'lat': -6.125312399999999, 'lng': 106.8335377} -6.125312
# 3   10000     4.5  {'lat': -6.302445899999999, 'lng': 106.8951559} -6.302446
# 4   94000     4.5             {'lat': -6.12419, 'lng': 106.839134} -6.124190
#
#          Long
# 0  106.827153
# 1  106.817125
# 2  106.833538
# 3  106.895156
# 4  106.839134
# 1/1 [==============================] - 0s 148ms/step
#    User_Id  Place_Id                         Place_Name       Category  \
# 0      101         1                   Monumen Nasional         Budaya
# 1      102         2                           Kota Tua         Budaya
# 2      103         3                      Dunia Fantasi  Taman Hiburan
# 3      104         4  Taman Mini Indonesia Indah (TMII)  Taman Hiburan
# 4      105         5           Atlantis Water Adventure  Taman Hiburan
# 5      106         6            Taman Impian Jaya Ancol  Taman Hiburan
# 6      107         7             Kebun Binatang Ragunan     Cagar Alam
# 7      108         8                      Ocean Ecopark  Taman Hiburan
# 8      109         9                   Pelabuhan Marina         Bahari
# 9      110        10                       Pulau Tidung         Bahari
#
#    predicted_rating
# 0          0.520352
# 1          0.590189
# 2          0.408963
# 3          0.525539
# 4          0.680688
# 5          0.423090
# 6          0.412736
# 7          0.687991
# 8          0.626908
# 9          0.436353

# %%
# Print the top 10 recommendations with the highest rating, considering only one recommendation per place
print("Top 10 Cultural Recommendations:")
seen_places = set()
recommendations_count = 0
for index, row in grouped_recommendations.iterrows():
    place_id = place_encoded_to_place[row['place']]
    if place_id not in seen_places:
        place_details = place[place['Place_Id'] == place_id]
        category = place_details['Category'].iloc[0]

        # Check if the place belongs to the 'Culture' category
        if category == 'Cagar Alam':
            place_name = place_details['Place_Name'].iloc[0]
            price = place_details['Price'].iloc[0]
            rating = place_details['Rating'].iloc[0]

            print(f"Place ID: {place_id}")
            print(f"Place Name: {place_name}")
            print(f"Category: {category}")
            print(f"Price: {price}")
            print(f"Rating: {rating}")
            print("\n")

            seen_places.add(place_id)
            recommendations_count += 1

            if recommendations_count >= 10:
                break
# Out:
# Top 10 Cultural Recommendations:
# Place ID: 7
# Place Name: Kebun Binatang Ragunan
# Category: Cagar Alam
# Price: 4000
# Rating: 4.5
#
#
# Place ID: 93
# Place Name: Gembira Loka Zoo
# Category: Cagar Alam
# Price: 60000
# Rating: 4.5
#
#
# Place ID: 211
# Place Name: GunungTangkuban perahu
# Category: Cagar Alam
# Price: 30000
# Rating: 4.5
#
#
# Place ID: 215
# Place Name: Taman Hutan Raya Ir. H. Djuanda
# Category: Cagar Alam
# Price: 15000
# Rating: 4.5
#
#
# Place ID: 217
# Place Name: Kebun Binatang Bandung
# Category: Cagar Alam
# Price: 20000
# Rating: 4.0
#
#
# Place ID: 218
# Place Name: Kawah Putih
# Category: Cagar Alam
# Price: 81000
# Rating: 4.5
#
#
# Place ID: 219
# Place Name: Tebing Karaton
# Category: Cagar Alam
# Price: 15000
# Rating: 4.5
#
#
# Place ID: 341
# Place Name: Hutan Wisata Tinjomoyo Semarang
# Category: Cagar Alam
# Price: 3000
# Rating: 4.3
#
#
# Place ID: 349
# Place Name: Wisata Mangrove Tapak
# Category: Cagar Alam
# Price: 5000
# Rating: 4.3
#
#
# Place ID: 355
# Place Name: Umbul Sidomukti
# Category: Cagar Alam
# Price: 75000
# Rating: 4.6

# %% [markdown]
# # save model

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.losses import MeanSquaredError
import os


# Memuat model dengan eksplisit menyertakan MeanSquaredError sebagai custom object
model = load_model('best_model.h5', custom_objects={'mse': MeanSquaredError()})

# %%
import joblib

joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']

# %%
place.to_csv('data/place_data.csv', index=False)

# %% [markdown]
# # API untuk Prediksi

# %%
import joblib

joblib.dump(user_to_user_encoded, 'user_to_user_encoded.pkl')
joblib.dump(place_to_place_encoded, 'place_to_place_encoded.pkl')
# Out:
# ['place_to_place_encoded.pkl']

# %%
from flask import Flask, request, jsonify
import tensorflow as tf
import joblib

app = Flask(__name__)

# Muat model terlatih
model = tf.keras.models.load_model('best_model.h5')

# Muat dictionary encoding
user_to_user_encoded = joblib.load('user_to_user_encoded.pkl')
place_to_place_encoded = joblib.load('place_to_place_encoded.pkl')

@app.route('/predict', methods=['POST'])
def predict():
    data = request.json
    user_id = data.get('user_id')
    place_id = data.get('place_id')

    user_encoded = user_to_user_encoded.get(user_id, None)
    place_encoded = place_to_place_encoded.get(place_id, None)

    if user_encoded is None or place_encoded is None:
        return jsonify({'error': 'User or Place not found'}), 400

    prediction = model.predict([[user_encoded], [place_encoded]])
    rating = prediction[0][0]

    return jsonify({'rating': rating})

if __name__ == '__main__':
    app.run(host='127.0.0.1', port=8092)
